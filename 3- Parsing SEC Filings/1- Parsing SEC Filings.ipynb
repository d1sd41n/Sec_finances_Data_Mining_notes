# %% [markdown]
# # Parsing SEC Documents - New Filings
#
# ## Introduction:
# In this notebook, we will go over how to parse SEC filing documents so you can extract different content from it and also logically organize the information. Making additional parsing more natural.
#
# At this point, it's safe to say that there is a remarkable amount of data available to individuals who seek high-quality financial data across a multitude of companies. This data can be used in a range of activities, from competition analysis to sentiment analysis. All it requires the individual to do is define a company they want, filing that belongs to that company, and the file that contains the information.
#
# Right now, we've defined a few ways to search for information depending on the type of search you want to conduct:
#
# 1. **Broad Search:**
# You don't care what is returned, and you want all the filings for a given period. This search is best acheived by parsing the different index directories. These directories list all the filings made for a given period. While probably the most simple to wrap your head around, this returned the most significant amount of data. Making data management a priority.
# 2. **Company Specific Search:**
# You are looking for a specific company and all their filings. There are currently two ways of doing this, using the CIK method or EDGAR Search Method. If you used the CIK method, you followed a technique that was similar to the Broad search method. Instead of looking at a specific period, you provide the CIK number, which will take you to a directory that contains all the filings that the company has made. Inside each filing folder, you would find all the files for that particular filing. If you didn't know the CIK number, you looked it up and did the CIK method. If you didn't know the CIK number you leveraged the EDGAR Search Method. Using this strategy meant requesting a URL that would direct you to a table containing all the filings for that company. However, this method required us to make a more complex script that would parse XML strings, paginating if the company had multiple pages, and reconstructing links to other directories.
# 3. **Filing Specific Search:**
# Here you want only a specific filing for a particular company. Again this can be achieved either using the CIK Search Method or the EDGAR Search Method. It solely depends on whether you have the information upfront or not. The only additional piece of information you needed was the accession number.
# 4. **Criteria Specific Search:**
# Here you were looking for a filing that has specific criteria, like the form being a 10K, a particular SIC number, or a particular date. This could only be achieved using the EDGAR Search Method, where you built a URL that contains the criteria you were searching on. In this case, your search was relatively simple because you only provided one rule. This search returns either an HTML or XML version of the data, which you would then have to parse.
# 5. **Multi-Criteria Search:**
# This is similar to a form specific search, but instead of only having one criterion, you were searching on multiple criteria. The only difference here is you had to build and request a URL that contained multiple parameters. Once you got the data, it was parsed the same.
# 6. **Text Search:**
# This type of search was done if you wanted to search on information found in the HEADER file for each filing. This allowed us to do the most complex searches as we could use boolean operators, wildcards, stemming, the order of evaluation, and phrase searching. While a powerful tool that allowed your searches to become very customized, it did require a decent working knowledge of both the HEADER file and search functionality. This was challenging as documentation is limited, requiring a fair amount of experimentation.
#
# Regardless of your particular search method, each can give you access to filings that match the criteria you specified. Once you've landed on the filing, you want to scrape. You can begin the process of extracting the information.
#
# ## Libraries
# Surprisingly, we don't need that many libraries to scrape the SEC filing. In this particular tutorial, we will use the following libraries:
#
# 1. BeautifulSoup - This will be used to parse the actual text file content.
# 2. Requests - This will be used to request the text file from the URL provided.
# 3. Unicodedata - The text that is sent back is messy and will need to be cleaned up. We can use unicodedata to do that.
# 4. Re - This is the RegEx library for python and will make looking for keywords smooth and quick.
# Depending on your specific needs, you may need extra libraries but at this point, for simplicity, we will keep it to these four.

# %%
import re
import requests
import unicodedata
from bs4 import BeautifulSoup

# %% [markdown]
# ## Define Text Normalization Function
# The text is a mess, so we will need to normalize it. However, we can't rely on just the unicodedata library to help us. Some windows_1252_characters will provide some challenges. I found a solution on Stack Overflow that'll help us normalize the remaining portions of the data. All this function does is take a string, finds any qualifying matches, decodes those matches, and then replaces them in the string. In essence, it's just cleaning up the characters that weren't decoded by the unicodedata library.

# %%
def restore_windows_1252_characters(restore_string):
    """
        Replace C1 control characters in the Unicode string s by the
        characters at the corresponding code points in Windows-1252,
        where possible.
    """

    def to_windows_1252(match):
        try:
            return bytes([ord(match.group(0))]).decode('windows-1252')
        except UnicodeDecodeError:
            # No character at the corresponding code point: remove it.
            return ''
        
    return re.sub(r'[\u0080-\u0099]', to_windows_1252, restore_string)

# %% [markdown]
# ## Grab the Document Content
# Let's grab the document first. In my case, I have a URL that'll direct me to a text file found on the SEC website. I take the URL, request the content using a GET request, store the response in a variable called response, and then pass through the content into our BeautifulSoup parser object. Make sure to specify the lxml parser.
#
# ## Old Vs. New
# This is an excellent time to mention document structure and how structure changes depending on the filing's age. In newer filings, the HTML code is very well structured, meaning the tags are correct and allow us to go into extraordinary detail when we parse the info. In older filings, the HTML code is not well strucutred. To give you an idea of what you'll encounter, entire content will b stored in tags called <PAGE> and tables that don't have normal td and tr elements. This is just listing a few.
#
# Unfortunately, the scraping strategy we leverage will depend on the age of the filing. Additionally, I can't say with confidence at what point in time a filing is considered "old" as I haven't explored enough filings to find a pattern. I'm assuming most of us don't need to go far back in time to collect data, so this series focuses on the "newer" filings. In other words, those filings that have will define HTML code inside the text file.
#
# If you're curious as to what an example of an older and newer filing would look like, I've provided a link to two different text files for two separate filings.
#
# #### Newer Filing:
#
# https://www.sec.gov/Archives/edgar/data/1166036/000110465904027382/0001104659-04-027382.txt
#
# #### Older Filing:
#
# https://www.sec.gov/Archives/edgar/data/1750/0000912057-94-002818.txt

# %%
# define the url to specific html_text file
new_html_text = r"https://www.sec.gov/Archives/edgar/data/1166036/000110465904027382/0001104659-04-027382.txt"

# grab the response
response = requests.get(new_html_text)

# pass it through the parser, in this case let's just use lxml because the tags seem to follow xml.
soup = BeautifulSoup(response.content, 'lxml')

# %% [markdown]
# ## Defining Our Master Dictionary To House Filings
# Assuming you want to parse more than one filing, we will need to create a structure that allows for a natural hierarchy. This hierarchy will provide a defined path to each component of our filing, while still being flexible enough to grow as you need to add different pieces.
#
# At the highest level, we have our master_filings_dict, which will contain all the filings we scrape. For this to work, we need a mechanism that provides a unique identifier to serve as our dictionary key. In this case, the accession_number will work perfectly as it's unique for every filing.
#
# From here, we will have an accession dictionary, which will contain two parts:
#
# 1. One for the SEC Header content, which is found at the top of every filing.
# 2. One for the filing documents, which will contain all the documents for a filing.
#
# To be clear, a filing can contain multiple documents. For example, a filing can include a 10-K document and an exhibit document. You must remember this it will help you understand the upcoming sections.

# %%
# define a dictionary that will house all filings.
master_filings_dict = {}

# let's use the accession number as the key. This 
accession_number = '0001104659-04-027382'

# add a new level to our master_filing_dict, this will also be a dictionary.
master_filings_dict[accession_number] = {}

# this dictionary will contain two keys, the sec header content, and a documents key.
master_filings_dict[accession_number]['sec_header_content'] = {}
master_filings_dict[accession_number]['filing_documents'] = None

# %% [markdown]
# ## Examing the SEC-Header Tag
# Honestly, I would not want to scrape this poriton of the filing. The reason why is it's a bunch text that isn't strucutred well. Also you probably can get this information from somewhere else in the filing and have it be more structured. However, there may be some information in this part that people want. Here's a simple solution. Grab first, and parse later.

# %%
# grab the sec-header tag, so we can store it in the master filing dictionary.
sec_header_tag = soup.find('sec-header')

# store the tag in the dictionary just as is.
master_filings_dict[accession_number]['sec_header_content']['sec_header_code'] = sec_header_tag

# display the sec header tag, so you can see how it looks.
display(sec_header_tag)
# Out:
# <sec-header>0001104659-04-027382.hdr.sgml : 20040913
# <acceptance-datetime>20040913074905
# ACCESSION NUMBER:		0001104659-04-027382
# CONFORMED SUBMISSION TYPE:	8-K/A
# PUBLIC DOCUMENT COUNT:		7
# CONFORMED PERIOD OF REPORT:	20040730
# ITEM INFORMATION:		Completion of Acquisition or Disposition of Assets
# ITEM INFORMATION:		Financial Statements and Exhibits
# FILED AS OF DATE:		20040913
# DATE AS OF CHANGE:		20040913
#
# FILER:
#
# 	COMPANY DATA:
# 		COMPANY CONFORMED NAME:			MARKWEST ENERGY PARTNERS L P
# 		CENTRAL INDEX KEY:			0001166036
# 		STANDARD INDUSTRIAL CLASSIFICATION:	CRUDE PETROLEUM &amp; NATURAL GAS [1311]
# 		IRS NUMBER:				270005456
# 		FISCAL YEAR END:			1231
#
# 	FILING VALUES:
# 		FORM TYPE:		8-K/A
# 		SEC ACT:		1934 Act
# 		SEC FILE NUMBER:	001-31239
# 		FILM NUMBER:		041026639
#
# 	BUSINESS ADDRESS:
# 		STREET 1:		155 INVERNESS DR WEST
# 		STREET 2:		STE 200
# 		CITY:			ENGLEWOOD
# 		STATE:			CO
# 		ZIP:			80112
# 		BUSINESS PHONE:		303-925-9275
#
# 	MAIL ADDRESS:
# 		STREET 1:		155 INVERNESS DR WEST
# 		STREET 2:		STE 200
# 		CITY:			ENGLEWOOD
# 		STATE:			CO
# 		ZIP:			80112
# </acceptance-datetime></sec-header>

# %%
master_filings_dict
# Out:
# {'0001104659-04-027382': {'sec_header_content': {'sec_header_code': <sec-header>0001104659-04-027382.hdr.sgml : 20040913
#    <acceptance-datetime>20040913074905
#    ACCESSION NUMBER:		0001104659-04-027382
#    CONFORMED SUBMISSION TYPE:	8-K/A
#    PUBLIC DOCUMENT COUNT:		7
#    CONFORMED PERIOD OF REPORT:	20040730
#    ITEM INFORMATION:		Completion of Acquisition or Disposition of Assets
#    ITEM INFORMATION:		Financial Statements and Exhibits
#    FILED AS OF DATE:		20040913
#    DATE AS OF CHANGE:		20040913
#
#    FILER:
#
#    	COMPANY DATA:
#    		COMPANY CONFORMED NAME:			MARKWEST ENERGY PARTNERS L P
#    		CENTRAL INDEX KEY:			0001166036
#    		STANDARD INDUSTRIAL CLASSIFICATION:	CRUDE PETROLEUM &amp; NATURAL GAS [1311]
#    		IRS NUMBER:				270005456
#    		FISCAL YEAR END:			1231
#
#    	FILING VALUES:
#    		FORM TYPE:		8-K/A
#    		SEC ACT:		1934 Act
#    		SEC FILE NUMBER:	001-31239
#    		FILM NUMBER:		041026639
#
#    	BUSINESS ADDRESS:
#    		STREET 1:		155 INVERNESS DR WEST
#    		STREET 2:		STE 200
#    		CITY:			ENGLEWOOD
#    		STATE:			CO
#    		ZIP:			80112
#    		BUSINESS PHONE:		303-925-9275
#
#    	MAIL ADDRESS:
#    		STREET 1:		155 INVERNESS DR WEST
#    		STREET 2:		STE 200
#    		CITY:			ENGLEWOOD
#    		STATE:			CO
#    		ZIP:			80112
#    </acceptance-datetime></sec-header>}, 'filing_documents': None}}

# %% [markdown]
# ## Parsing the documents
# Now the fun part, grabbing all the documents. This isn't too bad, just do a find all with the document tag and loop through the results. However, I want to take some time and give you an idea of the natural structure of the text file.
#
# At this point, we know that a filing contains two main elements:
#
# 1. A header
# 2. A document collection.
#
# We've seen from up above that the header while challenging to parse, contains more information like time of filing, company info, and more contextual data. Some of this data requires going through multiple levels to get it. For example, the company zip requires going into the header, then the filer, then the business address, and finally, you'll arrive at the company zip code.
#
# The reason I mention this is because it helps you understand that some of the info exists deep in the document hierarchy. To get this info means traversing the hierarchy, in some cases, multiple times for each document in a filing. Continuing, a document has another hierarchy:
#
# 1. type
# 2. sequence
# 3. filename
# 4. description
# 5. text
#
# Additionally, the text tag contains all the HTML code for our document, which has its own structure that can change depending on the document you're looking at. The vital point to take away is that a hierarchy is there and can be beneficial for storage purposes and searching.
#
# In the code I present below, I try to maintain the hierarchy as much as possible — no sense of wasting something that is already there. However, I do modify it in some instances to meet my requirements. For example, I break each document into pages and store those pages in a document dictionary. I also have search results stored at a page level and, in some cases, at a document level.
#
# It's not to say that one is better than the other, but more to show that you can approach this task in multiple ways. The way you decide to go with will depend on the problem you're trying to solve.

# %%
# initalize the dictionary that will house all of our documents
master_document_dict = {}

# find all the documents in the filing.
for filing_document in soup.find_all('document'):
    
    # define the document type, found under the <type> tag, this will serve as our key for the dictionary.
    document_id = filing_document.type.find(text=True, recursive=False).strip()
    
    # here are the other parts if you want them.
    document_sequence = filing_document.sequence.find(text=True, recursive=False).strip()
    document_filename = filing_document.filename.find(text=True, recursive=False).strip()
    document_description = filing_document.description.find(text=True, recursive=False).strip()
    
    # initalize our document dictionary
    master_document_dict[document_id] = {}
    
    # add the different parts, we parsed up above.
    master_document_dict[document_id]['document_sequence'] = document_sequence
    master_document_dict[document_id]['document_filename'] = document_filename
    master_document_dict[document_id]['document_description'] = document_description
    
    # store the document itself, this portion extracts the HTML code. We will have to reparse it later.
    master_document_dict[document_id]['document_code'] = filing_document.extract()
    
    # grab the text portion of the document, this will be used to split the document into pages.
    filing_doc_text = filing_document.find('text').extract()
    
    # find all the thematic breaks, these help define page numbers and page breaks.
    all_thematic_breaks = filing_doc_text.find_all('hr',{'width':'100%'})
    
    # convert all thematic breaks to a string so it can be used for parsing
    all_thematic_breaks = [str(thematic_break) for thematic_break in all_thematic_breaks]
    
    # prep the document text for splitting, this means converting it to a string.
    filing_doc_string = str(filing_doc_text)

    # handle the case where there are thematic breaks.
    if len(all_thematic_breaks) > 0:
    
        # define the regex delimiter pattern, this would just be all of our thematic breaks.
        regex_delimiter_pattern = '|'.join(map(re.escape, all_thematic_breaks))
        
        # split the document along each thematic break.
        split_filing_string = re.split(regex_delimiter_pattern, filing_doc_string)
        
        # store the document itself
        master_document_dict[document_id]['pages_code'] = split_filing_string
    
    # handle the case where there are no thematic breaks.
    elif len(all_thematic_breaks) == 0:

        # handles so it will display correctly.
        split_filing_string = all_thematic_breaks
        
        # store the document as is, since there are no thematic breaks. In other words, no splitting.
        master_document_dict[document_id]['pages_code'] = [filing_doc_string]
        
    # display some information to the user.
    print('-'*80)
    print('The document {} was parsed.'.format(document_id))
    print('There was {} thematic breaks(s) found.'.format(len(all_thematic_breaks)))
    

# store the documents in the master_filing_dictionary.
master_filings_dict[accession_number]['filing_documents'] = master_document_dict

print('-'*80)
print('All the documents for filing {} were parsed and stored.'.format(accession_number))
# Out:
# --------------------------------------------------------------------------------
# The document 8-K/A was parsed.
# There was 31 thematic breaks(s) found.
# --------------------------------------------------------------------------------
# The document EX-2.1 was parsed.
# There was 37 thematic breaks(s) found.
# --------------------------------------------------------------------------------
# The document EX-4.1 was parsed.
# There was 35 thematic breaks(s) found.
# --------------------------------------------------------------------------------
# The document EX-4.2 was parsed.
# There was 20 thematic breaks(s) found.
# --------------------------------------------------------------------------------
# The document EX-23.1 was parsed.
# There was 0 thematic breaks(s) found.
# --------------------------------------------------------------------------------
# The document EX-99.1 was parsed.
# There was 235 thematic breaks(s) found.
# --------------------------------------------------------------------------------
# The document EX-99.2 was parsed.
# There was 13 thematic breaks(s) found.
# --------------------------------------------------------------------------------
# All the documents for filing 0001104659-04-027382 were parsed and stored.

# %% [markdown]
# ## Normalizing Text
# Okay, so at this point, we are in pretty good shape. We have all the documents, they've been split into their pages and have been stored in the dictionary. From here, we can proceed to further data cleaning and transformation. Now, I will add a little bit of a disclosure. Technically, we could have done some of this cleaning up above, but for organizational purposes, I decided to loop through everything again and parse it that way.
#
# This would increase the amount of time it will take to run your code, but it is easier to follow. I will provide a more "optimized" script that will do the cleaning up above and store that on GitHub. Another drawback to this method is that I pass through all the code for each page back through BeautifulSoup. The reason why is the tags have been slightly messed up during the extraction and have to be fixed. I haven't run into many hiccups with this, but there is no guarantee that this will be the case for every filing type.
#
# You might be asking why I am doing this method if there are these drawbacks. Well, I find I have a little bit more control over the process when it comes to leveraging patterns in the HTML code. These patterns will help us to find section headers, titles, and other "meaningful" components of the page that will provide context as to what it contains. This will serve to be useful down the road when we want to look for particular parts of a paragraph.

# %%
# first grab all the documents
filing_documents = master_filings_dict[accession_number]['filing_documents']

# loop through each document
for document_id in filing_documents:
    # display some info to give status updates.
    print('-'*80)
    print('Pulling document {} for text normilzation.'.format(document_id))
    
    # grab all the pages for that document
    document_pages = filing_documents[document_id]['pages_code']
    
    # page length
    pages_length = len(filing_documents[document_id]['pages_code'])
    
    # initalize a dictionary that'll house our repaired html code for each page.
    repaired_pages = {}
    
    # initalize a dictionary that'll house all the normalized text.
    normalized_text = {}

    # loop through each page in that document.
    for index, page in enumerate(document_pages):
        
        # pass it through the parser. NOTE I AM USING THE HTML5 PARSER. YOU MUST USE THIS TO FIX BROKEN TAGS.
        page_soup = BeautifulSoup(page,'html5')
        
        # grab all the text, notice I go to the BODY tag to do this
        page_text = page_soup.html.body.get_text(' ',strip = True)
        
        # normalize the text, remove messy characters. Additionally, restore missing window characters.
        page_text_norm = restore_windows_1252_characters(unicodedata.normalize('NFKD', page_text)) 
        
        # Additional cleaning steps, removing double spaces, and new line breaks.
        page_text_norm = page_text_norm.replace('  ', ' ').replace('\n',' ')
        
        # define the page number.
        page_number = index + 1
        
        # add the normalized text to the list.
        normalized_text[page_number] = page_text_norm
        
        # add the repaired html to the list. Also now we have a page number as the key.
        repaired_pages[page_number] = page_soup
    
        # display a status to the user
        print('Page {} of {} from document {} has had their text normalized.'.format(index + 1, 
                                                                                     pages_length, 
                                                                                     document_id))

    # add the normalized text back to the document dictionary
    filing_documents[document_id]['pages_normalized_text'] = normalized_text
    
    # add the repaired html code back to the document dictionary
    filing_documents[document_id]['pages_code'] = repaired_pages
    
    # define the generated page numbers
    gen_page_numbers = list(repaired_pages.keys())
    
    # add the page numbers we have.
    filing_documents[document_id]['pages_numbers_generated'] = gen_page_numbers    
    
    # display a status to the user.
    print('All the pages from document {} have been normalized.'.format(document_id))
# Out:
# --------------------------------------------------------------------------------
# Pulling document 8-K/A for text normilzation.
# /home/dan/anaconda3/lib/python3.6/site-packages/bs4/__init__.py:181: UserWarning: No parser was explicitly specified, so I'm using the best available HTML parser for this system ("html5lib"). This usually isn't a problem, but if you run this code on another system, or in a different virtual environment, it may use a different parser and behave differently.
#
# The code that caused this warning is on line 193 of the file /home/dan/anaconda3/lib/python3.6/runpy.py. To get rid of this warning, change code that looks like this:
#
#  BeautifulSoup(YOUR_MARKUP})
#
# to this:
#
#  BeautifulSoup(YOUR_MARKUP, "html5lib")
#
#   markup_type=markup_type))
# Page 1 of 32 from document 8-K/A has had their text normalized.
# Page 2 of 32 from document 8-K/A has had their text normalized.
# Page 3 of 32 from document 8-K/A has had their text normalized.
# Page 4 of 32 from document 8-K/A has had their text normalized.
# Page 5 of 32 from document 8-K/A has had their text normalized.
# Page 6 of 32 from document 8-K/A has had their text normalized.
# Page 7 of 32 from document 8-K/A has had their text normalized.
# Page 8 of 32 from document 8-K/A has had their text normalized.
# Page 9 of 32 from document 8-K/A has had their text normalized.
# Page 10 of 32 from document 8-K/A has had their text normalized.
# Page 11 of 32 from document 8-K/A has had their text normalized.
# Page 12 of 32 from document 8-K/A has had their text normalized.
# Page 13 of 32 from document 8-K/A has had their text normalized.
# Page 14 of 32 from document 8-K/A has had their text normalized.
# Page 15 of 32 from document 8-K/A has had their text normalized.
# Page 16 of 32 from document 8-K/A has had their text normalized.
# Page 17 of 32 from document 8-K/A has had their text normalized.
# Page 18 of 32 from document 8-K/A has had their text normalized.
# Page 19 of 32 from document 8-K/A has had their text normalized.
# Page 20 of 32 from document 8-K/A has had their text normalized.
# Page 21 of 32 from document 8-K/A has had their text normalized.
# Page 22 of 32 from document 8-K/A has had their text normalized.
# Page 23 of 32 from document 8-K/A has had their text normalized.
# Page 24 of 32 from document 8-K/A has had their text normalized.
# Page 25 of 32 from document 8-K/A has had their text normalized.
# Page 26 of 32 from document 8-K/A has had their text normalized.
# Page 27 of 32 from document 8-K/A has had their text normalized.
# Page 28 of 32 from document 8-K/A has had their text normalized.
# Page 29 of 32 from document 8-K/A has had their text normalized.
# Page 30 of 32 from document 8-K/A has had their text normalized.
# Page 31 of 32 from document 8-K/A has had their text normalized.
# Page 32 of 32 from document 8-K/A has had their text normalized.
# All the pages from document 8-K/A have been normalized.
# --------------------------------------------------------------------------------
# Pulling document EX-2.1 for text normilzation.
# Page 1 of 38 from document EX-2.1 has had their text normalized.
# Page 2 of 38 from document EX-2.1 has had their text normalized.
# Page 3 of 38 from document EX-2.1 has had their text normalized.
# Page 4 of 38 from document EX-2.1 has had their text normalized.
# Page 5 of 38 from document EX-2.1 has had their text normalized.
# Page 6 of 38 from document EX-2.1 has had their text normalized.
# Page 7 of 38 from document EX-2.1 has had their text normalized.
# Page 8 of 38 from document EX-2.1 has had their text normalized.
# Page 9 of 38 from document EX-2.1 has had their text normalized.
# Page 10 of 38 from document EX-2.1 has had their text normalized.
# Page 11 of 38 from document EX-2.1 has had their text normalized.
# Page 12 of 38 from document EX-2.1 has had their text normalized.
# Page 13 of 38 from document EX-2.1 has had their text normalized.
# Page 14 of 38 from document EX-2.1 has had their text normalized.
# Page 15 of 38 from document EX-2.1 has had their text normalized.
# Page 16 of 38 from document EX-2.1 has had their text normalized.
# Page 17 of 38 from document EX-2.1 has had their text normalized.
# Page 18 of 38 from document EX-2.1 has had their text normalized.
# Page 19 of 38 from document EX-2.1 has had their text normalized.
# Page 20 of 38 from document EX-2.1 has had their text normalized.
# Page 21 of 38 from document EX-2.1 has had their text normalized.
# Page 22 of 38 from document EX-2.1 has had their text normalized.
# Page 23 of 38 from document EX-2.1 has had their text normalized.
# Page 24 of 38 from document EX-2.1 has had their text normalized.
# Page 25 of 38 from document EX-2.1 has had their text normalized.
# Page 26 of 38 from document EX-2.1 has had their text normalized.
# Page 27 of 38 from document EX-2.1 has had their text normalized.
# Page 28 of 38 from document EX-2.1 has had their text normalized.
# Page 29 of 38 from document EX-2.1 has had their text normalized.
# Page 30 of 38 from document EX-2.1 has had their text normalized.
# Page 31 of 38 from document EX-2.1 has had their text normalized.
# Page 32 of 38 from document EX-2.1 has had their text normalized.
# Page 33 of 38 from document EX-2.1 has had their text normalized.
# Page 34 of 38 from document EX-2.1 has had their text normalized.
# Page 35 of 38 from document EX-2.1 has had their text normalized.
# Page 36 of 38 from document EX-2.1 has had their text normalized.
# Page 37 of 38 from document EX-2.1 has had their text normalized.
# Page 38 of 38 from document EX-2.1 has had their text normalized.
# All the pages from document EX-2.1 have been normalized.
# --------------------------------------------------------------------------------
# Pulling document EX-4.1 for text normilzation.
# Page 1 of 36 from document EX-4.1 has had their text normalized.
# Page 2 of 36 from document EX-4.1 has had their text normalized.
# Page 3 of 36 from document EX-4.1 has had their text normalized.
# Page 4 of 36 from document EX-4.1 has had their text normalized.
# Page 5 of 36 from document EX-4.1 has had their text normalized.
# Page 6 of 36 from document EX-4.1 has had their text normalized.
# Page 7 of 36 from document EX-4.1 has had their text normalized.
# Page 8 of 36 from document EX-4.1 has had their text normalized.
# Page 9 of 36 from document EX-4.1 has had their text normalized.
# Page 10 of 36 from document EX-4.1 has had their text normalized.
# Page 11 of 36 from document EX-4.1 has had their text normalized.
# Page 12 of 36 from document EX-4.1 has had their text normalized.
# Page 13 of 36 from document EX-4.1 has had their text normalized.
# Page 14 of 36 from document EX-4.1 has had their text normalized.
# Page 15 of 36 from document EX-4.1 has had their text normalized.
# Page 16 of 36 from document EX-4.1 has had their text normalized.
# Page 17 of 36 from document EX-4.1 has had their text normalized.
# Page 18 of 36 from document EX-4.1 has had their text normalized.
# Page 19 of 36 from document EX-4.1 has had their text normalized.
# Page 20 of 36 from document EX-4.1 has had their text normalized.
# Page 21 of 36 from document EX-4.1 has had their text normalized.
# Page 22 of 36 from document EX-4.1 has had their text normalized.
# Page 23 of 36 from document EX-4.1 has had their text normalized.
# Page 24 of 36 from document EX-4.1 has had their text normalized.
# Page 25 of 36 from document EX-4.1 has had their text normalized.
# Page 26 of 36 from document EX-4.1 has had their text normalized.
# Page 27 of 36 from document EX-4.1 has had their text normalized.
# Page 28 of 36 from document EX-4.1 has had their text normalized.
# Page 29 of 36 from document EX-4.1 has had their text normalized.
# Page 30 of 36 from document EX-4.1 has had their text normalized.
# Page 31 of 36 from document EX-4.1 has had their text normalized.
# Page 32 of 36 from document EX-4.1 has had their text normalized.
# Page 33 of 36 from document EX-4.1 has had their text normalized.
# Page 34 of 36 from document EX-4.1 has had their text normalized.
# Page 35 of 36 from document EX-4.1 has had their text normalized.
# Page 36 of 36 from document EX-4.1 has had their text normalized.
# All the pages from document EX-4.1 have been normalized.
# --------------------------------------------------------------------------------
# Pulling document EX-4.2 for text normilzation.
# Page 1 of 21 from document EX-4.2 has had their text normalized.
# Page 2 of 21 from document EX-4.2 has had their text normalized.
# Page 3 of 21 from document EX-4.2 has had their text normalized.
# Page 4 of 21 from document EX-4.2 has had their text normalized.
# Page 5 of 21 from document EX-4.2 has had their text normalized.
# Page 6 of 21 from document EX-4.2 has had their text normalized.
# Page 7 of 21 from document EX-4.2 has had their text normalized.
# Page 8 of 21 from document EX-4.2 has had their text normalized.
# Page 9 of 21 from document EX-4.2 has had their text normalized.
# Page 10 of 21 from document EX-4.2 has had their text normalized.
# Page 11 of 21 from document EX-4.2 has had their text normalized.
# Page 12 of 21 from document EX-4.2 has had their text normalized.
# Page 13 of 21 from document EX-4.2 has had their text normalized.
# Page 14 of 21 from document EX-4.2 has had their text normalized.
# Page 15 of 21 from document EX-4.2 has had their text normalized.
# Page 16 of 21 from document EX-4.2 has had their text normalized.
# Page 17 of 21 from document EX-4.2 has had their text normalized.
# Page 18 of 21 from document EX-4.2 has had their text normalized.
# Page 19 of 21 from document EX-4.2 has had their text normalized.
# Page 20 of 21 from document EX-4.2 has had their text normalized.
# Page 21 of 21 from document EX-4.2 has had their text normalized.
# All the pages from document EX-4.2 have been normalized.
# --------------------------------------------------------------------------------
# Pulling document EX-23.1 for text normilzation.
# Page 1 of 1 from document EX-23.1 has had their text normalized.
# All the pages from document EX-23.1 have been normalized.
# --------------------------------------------------------------------------------
# Pulling document EX-99.1 for text normilzation.
# Page 1 of 236 from document EX-99.1 has had their text normalized.
# Page 2 of 236 from document EX-99.1 has had their text normalized.
# Page 3 of 236 from document EX-99.1 has had their text normalized.
# Page 4 of 236 from document EX-99.1 has had their text normalized.
# Page 5 of 236 from document EX-99.1 has had their text normalized.
# Page 6 of 236 from document EX-99.1 has had their text normalized.
# Page 7 of 236 from document EX-99.1 has had their text normalized.
# Page 8 of 236 from document EX-99.1 has had their text normalized.
# Page 9 of 236 from document EX-99.1 has had their text normalized.
# Page 10 of 236 from document EX-99.1 has had their text normalized.
# Page 11 of 236 from document EX-99.1 has had their text normalized.
# Page 12 of 236 from document EX-99.1 has had their text normalized.
# Page 13 of 236 from document EX-99.1 has had their text normalized.
# Page 14 of 236 from document EX-99.1 has had their text normalized.
# Page 15 of 236 from document EX-99.1 has had their text normalized.
# Page 16 of 236 from document EX-99.1 has had their text normalized.
# Page 17 of 236 from document EX-99.1 has had their text normalized.
# Page 18 of 236 from document EX-99.1 has had their text normalized.
# Page 19 of 236 from document EX-99.1 has had their text normalized.
# Page 20 of 236 from document EX-99.1 has had their text normalized.
# Page 21 of 236 from document EX-99.1 has had their text normalized.
# Page 22 of 236 from document EX-99.1 has had their text normalized.
# Page 23 of 236 from document EX-99.1 has had their text normalized.
# Page 24 of 236 from document EX-99.1 has had their text normalized.
# Page 25 of 236 from document EX-99.1 has had their text normalized.
# Page 26 of 236 from document EX-99.1 has had their text normalized.
# Page 27 of 236 from document EX-99.1 has had their text normalized.
# Page 28 of 236 from document EX-99.1 has had their text normalized.
# Page 29 of 236 from document EX-99.1 has had their text normalized.
# Page 30 of 236 from document EX-99.1 has had their text normalized.
# Page 31 of 236 from document EX-99.1 has had their text normalized.
# Page 32 of 236 from document EX-99.1 has had their text normalized.
# Page 33 of 236 from document EX-99.1 has had their text normalized.
# Page 34 of 236 from document EX-99.1 has had their text normalized.
# Page 35 of 236 from document EX-99.1 has had their text normalized.
# Page 36 of 236 from document EX-99.1 has had their text normalized.
# Page 37 of 236 from document EX-99.1 has had their text normalized.
# Page 38 of 236 from document EX-99.1 has had their text normalized.
# Page 39 of 236 from document EX-99.1 has had their text normalized.
# Page 40 of 236 from document EX-99.1 has had their text normalized.
# Page 41 of 236 from document EX-99.1 has had their text normalized.
# Page 42 of 236 from document EX-99.1 has had their text normalized.
# Page 43 of 236 from document EX-99.1 has had their text normalized.
# Page 44 of 236 from document EX-99.1 has had their text normalized.
# Page 45 of 236 from document EX-99.1 has had their text normalized.
# Page 46 of 236 from document EX-99.1 has had their text normalized.
# Page 47 of 236 from document EX-99.1 has had their text normalized.
# Page 48 of 236 from document EX-99.1 has had their text normalized.
# Page 49 of 236 from document EX-99.1 has had their text normalized.
# Page 50 of 236 from document EX-99.1 has had their text normalized.
# Page 51 of 236 from document EX-99.1 has had their text normalized.
# Page 52 of 236 from document EX-99.1 has had their text normalized.
# Page 53 of 236 from document EX-99.1 has had their text normalized.
# Page 54 of 236 from document EX-99.1 has had their text normalized.
# Page 55 of 236 from document EX-99.1 has had their text normalized.
# Page 56 of 236 from document EX-99.1 has had their text normalized.
# Page 57 of 236 from document EX-99.1 has had their text normalized.
# Page 58 of 236 from document EX-99.1 has had their text normalized.
# Page 59 of 236 from document EX-99.1 has had their text normalized.
# Page 60 of 236 from document EX-99.1 has had their text normalized.
# Page 61 of 236 from document EX-99.1 has had their text normalized.
# Page 62 of 236 from document EX-99.1 has had their text normalized.
# Page 63 of 236 from document EX-99.1 has had their text normalized.
# Page 64 of 236 from document EX-99.1 has had their text normalized.
# Page 65 of 236 from document EX-99.1 has had their text normalized.
# Page 66 of 236 from document EX-99.1 has had their text normalized.
# Page 67 of 236 from document EX-99.1 has had their text normalized.
# Page 68 of 236 from document EX-99.1 has had their text normalized.
# Page 69 of 236 from document EX-99.1 has had their text normalized.
# Page 70 of 236 from document EX-99.1 has had their text normalized.
# Page 71 of 236 from document EX-99.1 has had their text normalized.
# Page 72 of 236 from document EX-99.1 has had their text normalized.
# Page 73 of 236 from document EX-99.1 has had their text normalized.
# Page 74 of 236 from document EX-99.1 has had their text normalized.
# Page 75 of 236 from document EX-99.1 has had their text normalized.
# Page 76 of 236 from document EX-99.1 has had their text normalized.
# Page 77 of 236 from document EX-99.1 has had their text normalized.
# Page 78 of 236 from document EX-99.1 has had their text normalized.
# Page 79 of 236 from document EX-99.1 has had their text normalized.
# Page 80 of 236 from document EX-99.1 has had their text normalized.
# Page 81 of 236 from document EX-99.1 has had their text normalized.
# Page 82 of 236 from document EX-99.1 has had their text normalized.
# Page 83 of 236 from document EX-99.1 has had their text normalized.
# Page 84 of 236 from document EX-99.1 has had their text normalized.
# Page 85 of 236 from document EX-99.1 has had their text normalized.
# Page 86 of 236 from document EX-99.1 has had their text normalized.
# Page 87 of 236 from document EX-99.1 has had their text normalized.
# Page 88 of 236 from document EX-99.1 has had their text normalized.
# Page 89 of 236 from document EX-99.1 has had their text normalized.
# Page 90 of 236 from document EX-99.1 has had their text normalized.
# Page 91 of 236 from document EX-99.1 has had their text normalized.
# Page 92 of 236 from document EX-99.1 has had their text normalized.
# Page 93 of 236 from document EX-99.1 has had their text normalized.
# Page 94 of 236 from document EX-99.1 has had their text normalized.
# Page 95 of 236 from document EX-99.1 has had their text normalized.
# Page 96 of 236 from document EX-99.1 has had their text normalized.
# Page 97 of 236 from document EX-99.1 has had their text normalized.
# Page 98 of 236 from document EX-99.1 has had their text normalized.
# Page 99 of 236 from document EX-99.1 has had their text normalized.
# Page 100 of 236 from document EX-99.1 has had their text normalized.
# Page 101 of 236 from document EX-99.1 has had their text normalized.
# Page 102 of 236 from document EX-99.1 has had their text normalized.
# Page 103 of 236 from document EX-99.1 has had their text normalized.
# Page 104 of 236 from document EX-99.1 has had their text normalized.
# Page 105 of 236 from document EX-99.1 has had their text normalized.
# Page 106 of 236 from document EX-99.1 has had their text normalized.
# Page 107 of 236 from document EX-99.1 has had their text normalized.
# Page 108 of 236 from document EX-99.1 has had their text normalized.
# Page 109 of 236 from document EX-99.1 has had their text normalized.
# Page 110 of 236 from document EX-99.1 has had their text normalized.
# Page 111 of 236 from document EX-99.1 has had their text normalized.
# Page 112 of 236 from document EX-99.1 has had their text normalized.
# Page 113 of 236 from document EX-99.1 has had their text normalized.
# Page 114 of 236 from document EX-99.1 has had their text normalized.
# Page 115 of 236 from document EX-99.1 has had their text normalized.
# Page 116 of 236 from document EX-99.1 has had their text normalized.
# Page 117 of 236 from document EX-99.1 has had their text normalized.
# Page 118 of 236 from document EX-99.1 has had their text normalized.
# Page 119 of 236 from document EX-99.1 has had their text normalized.
# Page 120 of 236 from document EX-99.1 has had their text normalized.
# Page 121 of 236 from document EX-99.1 has had their text normalized.
# Page 122 of 236 from document EX-99.1 has had their text normalized.
# Page 123 of 236 from document EX-99.1 has had their text normalized.
# Page 124 of 236 from document EX-99.1 has had their text normalized.
# Page 125 of 236 from document EX-99.1 has had their text normalized.
# Page 126 of 236 from document EX-99.1 has had their text normalized.
# Page 127 of 236 from document EX-99.1 has had their text normalized.
# Page 128 of 236 from document EX-99.1 has had their text normalized.
# Page 129 of 236 from document EX-99.1 has had their text normalized.
# Page 130 of 236 from document EX-99.1 has had their text normalized.
# Page 131 of 236 from document EX-99.1 has had their text normalized.
# Page 132 of 236 from document EX-99.1 has had their text normalized.
# Page 133 of 236 from document EX-99.1 has had their text normalized.
# Page 134 of 236 from document EX-99.1 has had their text normalized.
# Page 135 of 236 from document EX-99.1 has had their text normalized.
# Page 136 of 236 from document EX-99.1 has had their text normalized.
# Page 137 of 236 from document EX-99.1 has had their text normalized.
# Page 138 of 236 from document EX-99.1 has had their text normalized.
# Page 139 of 236 from document EX-99.1 has had their text normalized.
# Page 140 of 236 from document EX-99.1 has had their text normalized.
# Page 141 of 236 from document EX-99.1 has had their text normalized.
# Page 142 of 236 from document EX-99.1 has had their text normalized.
# Page 143 of 236 from document EX-99.1 has had their text normalized.
# Page 144 of 236 from document EX-99.1 has had their text normalized.
# Page 145 of 236 from document EX-99.1 has had their text normalized.
# Page 146 of 236 from document EX-99.1 has had their text normalized.
# Page 147 of 236 from document EX-99.1 has had their text normalized.
# Page 148 of 236 from document EX-99.1 has had their text normalized.
# Page 149 of 236 from document EX-99.1 has had their text normalized.
# Page 150 of 236 from document EX-99.1 has had their text normalized.
# Page 151 of 236 from document EX-99.1 has had their text normalized.
# Page 152 of 236 from document EX-99.1 has had their text normalized.
# Page 153 of 236 from document EX-99.1 has had their text normalized.
# Page 154 of 236 from document EX-99.1 has had their text normalized.
# Page 155 of 236 from document EX-99.1 has had their text normalized.
# Page 156 of 236 from document EX-99.1 has had their text normalized.
# Page 157 of 236 from document EX-99.1 has had their text normalized.
# Page 158 of 236 from document EX-99.1 has had their text normalized.
# Page 159 of 236 from document EX-99.1 has had their text normalized.
# Page 160 of 236 from document EX-99.1 has had their text normalized.
# Page 161 of 236 from document EX-99.1 has had their text normalized.
# Page 162 of 236 from document EX-99.1 has had their text normalized.
# Page 163 of 236 from document EX-99.1 has had their text normalized.
# Page 164 of 236 from document EX-99.1 has had their text normalized.
# Page 165 of 236 from document EX-99.1 has had their text normalized.
# Page 166 of 236 from document EX-99.1 has had their text normalized.
# Page 167 of 236 from document EX-99.1 has had their text normalized.
# Page 168 of 236 from document EX-99.1 has had their text normalized.
# Page 169 of 236 from document EX-99.1 has had their text normalized.
# Page 170 of 236 from document EX-99.1 has had their text normalized.
# Page 171 of 236 from document EX-99.1 has had their text normalized.
# Page 172 of 236 from document EX-99.1 has had their text normalized.
# Page 173 of 236 from document EX-99.1 has had their text normalized.
# Page 174 of 236 from document EX-99.1 has had their text normalized.
# Page 175 of 236 from document EX-99.1 has had their text normalized.
# Page 176 of 236 from document EX-99.1 has had their text normalized.
# Page 177 of 236 from document EX-99.1 has had their text normalized.
# Page 178 of 236 from document EX-99.1 has had their text normalized.
# Page 179 of 236 from document EX-99.1 has had their text normalized.
# Page 180 of 236 from document EX-99.1 has had their text normalized.
# Page 181 of 236 from document EX-99.1 has had their text normalized.
# Page 182 of 236 from document EX-99.1 has had their text normalized.
# Page 183 of 236 from document EX-99.1 has had their text normalized.
# Page 184 of 236 from document EX-99.1 has had their text normalized.
# Page 185 of 236 from document EX-99.1 has had their text normalized.
# Page 186 of 236 from document EX-99.1 has had their text normalized.
# Page 187 of 236 from document EX-99.1 has had their text normalized.
# Page 188 of 236 from document EX-99.1 has had their text normalized.
# Page 189 of 236 from document EX-99.1 has had their text normalized.
# Page 190 of 236 from document EX-99.1 has had their text normalized.
# Page 191 of 236 from document EX-99.1 has had their text normalized.
# Page 192 of 236 from document EX-99.1 has had their text normalized.
# Page 193 of 236 from document EX-99.1 has had their text normalized.
# Page 194 of 236 from document EX-99.1 has had their text normalized.
# Page 195 of 236 from document EX-99.1 has had their text normalized.
# Page 196 of 236 from document EX-99.1 has had their text normalized.
# Page 197 of 236 from document EX-99.1 has had their text normalized.
# Page 198 of 236 from document EX-99.1 has had their text normalized.
# Page 199 of 236 from document EX-99.1 has had their text normalized.
# Page 200 of 236 from document EX-99.1 has had their text normalized.
# Page 201 of 236 from document EX-99.1 has had their text normalized.
# Page 202 of 236 from document EX-99.1 has had their text normalized.
# Page 203 of 236 from document EX-99.1 has had their text normalized.
# Page 204 of 236 from document EX-99.1 has had their text normalized.
# Page 205 of 236 from document EX-99.1 has had their text normalized.
# Page 206 of 236 from document EX-99.1 has had their text normalized.
# Page 207 of 236 from document EX-99.1 has had their text normalized.
# Page 208 of 236 from document EX-99.1 has had their text normalized.
# Page 209 of 236 from document EX-99.1 has had their text normalized.
# Page 210 of 236 from document EX-99.1 has had their text normalized.
# Page 211 of 236 from document EX-99.1 has had their text normalized.
# Page 212 of 236 from document EX-99.1 has had their text normalized.
# Page 213 of 236 from document EX-99.1 has had their text normalized.
# Page 214 of 236 from document EX-99.1 has had their text normalized.
# Page 215 of 236 from document EX-99.1 has had their text normalized.
# Page 216 of 236 from document EX-99.1 has had their text normalized.
# Page 217 of 236 from document EX-99.1 has had their text normalized.
# Page 218 of 236 from document EX-99.1 has had their text normalized.
# Page 219 of 236 from document EX-99.1 has had their text normalized.
# Page 220 of 236 from document EX-99.1 has had their text normalized.
# Page 221 of 236 from document EX-99.1 has had their text normalized.
# Page 222 of 236 from document EX-99.1 has had their text normalized.
# Page 223 of 236 from document EX-99.1 has had their text normalized.
# Page 224 of 236 from document EX-99.1 has had their text normalized.
# Page 225 of 236 from document EX-99.1 has had their text normalized.
# Page 226 of 236 from document EX-99.1 has had their text normalized.
# Page 227 of 236 from document EX-99.1 has had their text normalized.
# Page 228 of 236 from document EX-99.1 has had their text normalized.
# Page 229 of 236 from document EX-99.1 has had their text normalized.
# Page 230 of 236 from document EX-99.1 has had their text normalized.
# Page 231 of 236 from document EX-99.1 has had their text normalized.
# Page 232 of 236 from document EX-99.1 has had their text normalized.
# Page 233 of 236 from document EX-99.1 has had their text normalized.
# Page 234 of 236 from document EX-99.1 has had their text normalized.
# Page 235 of 236 from document EX-99.1 has had their text normalized.
# Page 236 of 236 from document EX-99.1 has had their text normalized.
# All the pages from document EX-99.1 have been normalized.
# --------------------------------------------------------------------------------
# Pulling document EX-99.2 for text normilzation.
# Page 1 of 14 from document EX-99.2 has had their text normalized.
# Page 2 of 14 from document EX-99.2 has had their text normalized.
# Page 3 of 14 from document EX-99.2 has had their text normalized.
# Page 4 of 14 from document EX-99.2 has had their text normalized.
# Page 5 of 14 from document EX-99.2 has had their text normalized.
# Page 6 of 14 from document EX-99.2 has had their text normalized.
# Page 7 of 14 from document EX-99.2 has had their text normalized.
# Page 8 of 14 from document EX-99.2 has had their text normalized.
# Page 9 of 14 from document EX-99.2 has had their text normalized.
# Page 10 of 14 from document EX-99.2 has had their text normalized.
# Page 11 of 14 from document EX-99.2 has had their text normalized.
# Page 12 of 14 from document EX-99.2 has had their text normalized.
# Page 13 of 14 from document EX-99.2 has had their text normalized.
# Page 14 of 14 from document EX-99.2 has had their text normalized.
# All the pages from document EX-99.2 have been normalized.

# %% [markdown]
# ## Additional Scraping and Context Extraction
# Alright, so now we are really in a good spot. From here on out, most of what we need to do will be relatively straight forward. By maintaining the natural hierarchy of the filing, and only expanding upon it when beneficial, we can now easily do further analysis of our data.
#
# What I'll demonstrate next is how to get different parts of each page. Additionally, I'll show you strategies for helping to infer the "context" of each page. For example, is a page a signature page, an exhibit page, or a section page? This will help give you context and help you get to where you need to be when getting info.
#
# Also, I'll demonstrate a strategy for how to search for keywords on each page.
#
# Now, like I mentioned up above, this might not be the fastest way to do it, but I am trying to layout this information in a logical format that flows from section to section. I am not concerned about the speed at this point; I'm worried about you following the steps I'm doing to clean my data. I will be posting a more "optimized" script on GitHub in the future.
#
# ## Defining Search Words
# Part of the next section is helping you gain a contextual understanding of each page/document. For example, you might have the belief that certain words like liability are only found in pages that talk about debt. If that is the case, then we can define a list of words and see if they are found on any of the pages of our document. If they are, we can store the matches in our master dictionary.
#
# With some background, let's define some words we might want to search for. Also, these are just guesses, and there is no guarantee that they will be the words we want. Unfortunately, you might have to read a few documents to determine the words that most appear in certain parts of the document.

# %%
search_dict = {
    
    # these could possibly be words that help us find pages that discuss financial statements.
    'financial_words':['liability', 'asset'],
    
    # these could possible be words that help us find sections that discuss administration topics.
    'admin_words':['administration', 'government']
}

# %%
# first grab all the documents
filing_documents = master_filings_dict[accession_number]['filing_documents']

# loop through each document
for document_id in filing_documents:
    
    
    ####################################
    # THIS WILL HANDLE THE WORD SEARCH #
    ####################################
    
    
    # let's grab the normalized text in this example, since it's cleaned and easier to search
    normalized_text_dict = filing_documents[document_id]['pages_normalized_text']  
            
    # initalize a dictionary to store all the tables we find.
    matching_words_dict = {}
    
    # define the number of pages
    page_length = len(normalized_text_dict)
    
    # loop through all the text
    for page_num in normalized_text_dict:
        
        # grab the actual text
        normalized_page_text = normalized_text_dict[page_num]
        
        # each page is going to be checked, so let's have another dictionary that'll house each pages result.
        matching_words_dict[page_num] = {}
        
        # loop through each word list in the search dictionary.
        for search_list in search_dict:
            
            # grab the list of words.
            list_of_words = search_dict[search_list]
            
            # lets see if any of the words are found
            matching_words = [word for word in list_of_words if word in normalized_page_text]
            
            '''
                Again, I know list comprehension might be hard to understand so I'll show you what the loop
                looks like.
                
                # initalize a list of matching words.
                matching_words = []
                
                # loop through the list of words.
                for word in list_of_words:
                
                    # check to see if it's in the text
                    if word in normalized_page_text:
                        
                        # if it is then add it to the list.
                        matching_words.append(word)
            '''
            
            # each page will have a set of results, list of words
            matching_words_dict[page_num][search_list] = {}
            
            # let's add the list of words we search to the matching words dictionary first.
            matching_words_dict[page_num][search_list]['list_of_words'] = list_of_words
            
            # next let's add the list of matchings words to the matching words dictionary.
            matching_words_dict[page_num][search_list]['matches'] = matching_words
            
        
        # display a status to the user.
        print('Page {} of {} from document {} has been searched.'.format(page_num, page_length, document_id))
    
    
    # display a status to the user.
    print('-'*80)    
    print('All the pages from document {} have been searched.'.format(document_id))    
    
    
    ####################################
    # THIS WILL HANDLE THE LINK SEARCH #
    ####################################
    
    
    # let's grab the all pages code.
    pages_dict = filing_documents[document_id]['pages_code']  
            
    # initalize a dictionary to store all the anchors we find.
    link_anchor_dict = {}
    
    # loop through each page
    for page_num in pages_dict:
        
        # grab the actual text
        page_code = pages_dict[page_num]
        
        # find all the anchors in the page, that have the attribute 'name'
        anchors_found = page_code.find_all('a',{'name':True})
        
        # number of anchors found
        num_found = len(anchors_found)
        
        # each page is going to be checked, so let's have another dictionary that'll house all the anchors found.
        link_anchor_dict[page_num]= {(anchor_id + 1): anchor for anchor_id, anchor in enumerate(anchors_found)}        
    
        # display a status to the user.
        print('Page {} of {} from document {} contained {} anchors with names.'.format(page_num, 
                                                                                       page_length, 
                                                                                       document_id, 
                                                                                       num_found))
    
    # display a status to the user.  
    print('All the pages from document {} have been scraped for anchors with names.'.format(document_id)) 
    print('-'*80)  
    
    
    #####################################
    # THIS WILL HANDLE THE TABLE SEARCH #
    #####################################
    
         
    # let's grab the all pages code.
    pages_dict = filing_documents[document_id]['pages_code']  
            
    # initalize a dictionary to store matching words.
    tables_dict = {}
    
    # loop through each page
    for page_num in pages_dict:
        
        # grab the actual text
        page_code = pages_dict[page_num]
        
        # find all the tables
        tables_found = page_code.find_all('table')
        
        # number of tables found
        num_found = len(tables_found)
        
        # each page is going to be checked, so let's have another dictionary that'll house all the tables found.
        tables_dict[page_num] = {(table_id + 1): table for table_id, table in enumerate(tables_found)}        
    
        # display a status to the user.
        print('Page {} of {} from document {} contained {} tables.'.format(page_num, page_length, document_id, num_found))
    
    # display a status to the user.  
    print('All the pages from document {} have been scraped for tables.'.format(document_id)) 
    print('-'*80)    
    
        
    # let's add the matching words dict to the document.
    filing_documents[document_id]['word_search'] = matching_words_dict  
    
    # let's add the matching tables dict to the document.
    filing_documents[document_id]['table_search'] = tables_dict
    
    # let's add the matching anchors dict to the document.
# Out:
# Page 1 of 32 from document 8-K/A has been searched.
# Page 2 of 32 from document 8-K/A has been searched.
# Page 3 of 32 from document 8-K/A has been searched.
# Page 4 of 32 from document 8-K/A has been searched.
# Page 5 of 32 from document 8-K/A has been searched.
# Page 6 of 32 from document 8-K/A has been searched.
# Page 7 of 32 from document 8-K/A has been searched.
# Page 8 of 32 from document 8-K/A has been searched.
# Page 9 of 32 from document 8-K/A has been searched.
# Page 10 of 32 from document 8-K/A has been searched.
# Page 11 of 32 from document 8-K/A has been searched.
# Page 12 of 32 from document 8-K/A has been searched.
# Page 13 of 32 from document 8-K/A has been searched.
# Page 14 of 32 from document 8-K/A has been searched.
# Page 15 of 32 from document 8-K/A has been searched.
# Page 16 of 32 from document 8-K/A has been searched.
# Page 17 of 32 from document 8-K/A has been searched.
# Page 18 of 32 from document 8-K/A has been searched.
# Page 19 of 32 from document 8-K/A has been searched.
# Page 20 of 32 from document 8-K/A has been searched.
# Page 21 of 32 from document 8-K/A has been searched.
# Page 22 of 32 from document 8-K/A has been searched.
# Page 23 of 32 from document 8-K/A has been searched.
# Page 24 of 32 from document 8-K/A has been searched.
# Page 25 of 32 from document 8-K/A has been searched.
# Page 26 of 32 from document 8-K/A has been searched.
# Page 27 of 32 from document 8-K/A has been searched.
# Page 28 of 32 from document 8-K/A has been searched.
# Page 29 of 32 from document 8-K/A has been searched.
# Page 30 of 32 from document 8-K/A has been searched.
# Page 31 of 32 from document 8-K/A has been searched.
# Page 32 of 32 from document 8-K/A has been searched.
# --------------------------------------------------------------------------------
# All the pages from document 8-K/A have been searched.
# Page 1 of 32 from document 8-K/A contained 0 anchors with names.
# Page 2 of 32 from document 8-K/A contained 0 anchors with names.
# Page 3 of 32 from document 8-K/A contained 0 anchors with names.
# Page 4 of 32 from document 8-K/A contained 0 anchors with names.
# Page 5 of 32 from document 8-K/A contained 0 anchors with names.
# Page 6 of 32 from document 8-K/A contained 0 anchors with names.
# Page 7 of 32 from document 8-K/A contained 0 anchors with names.
# Page 8 of 32 from document 8-K/A contained 0 anchors with names.
# Page 9 of 32 from document 8-K/A contained 0 anchors with names.
# Page 10 of 32 from document 8-K/A contained 0 anchors with names.
# Page 11 of 32 from document 8-K/A contained 0 anchors with names.
# Page 12 of 32 from document 8-K/A contained 0 anchors with names.
# Page 13 of 32 from document 8-K/A contained 0 anchors with names.
# Page 14 of 32 from document 8-K/A contained 0 anchors with names.
# Page 15 of 32 from document 8-K/A contained 0 anchors with names.
# Page 16 of 32 from document 8-K/A contained 0 anchors with names.
# Page 17 of 32 from document 8-K/A contained 0 anchors with names.
# Page 18 of 32 from document 8-K/A contained 0 anchors with names.
# Page 19 of 32 from document 8-K/A contained 0 anchors with names.
# Page 20 of 32 from document 8-K/A contained 0 anchors with names.
# Page 21 of 32 from document 8-K/A contained 0 anchors with names.
# Page 22 of 32 from document 8-K/A contained 0 anchors with names.
# Page 23 of 32 from document 8-K/A contained 0 anchors with names.
# Page 24 of 32 from document 8-K/A contained 0 anchors with names.
# Page 25 of 32 from document 8-K/A contained 0 anchors with names.
# Page 26 of 32 from document 8-K/A contained 0 anchors with names.
# Page 27 of 32 from document 8-K/A contained 0 anchors with names.
# Page 28 of 32 from document 8-K/A contained 0 anchors with names.
# Page 29 of 32 from document 8-K/A contained 0 anchors with names.
# Page 30 of 32 from document 8-K/A contained 0 anchors with names.
# Page 31 of 32 from document 8-K/A contained 0 anchors with names.
# Page 32 of 32 from document 8-K/A contained 0 anchors with names.
# All the pages from document 8-K/A have been scraped for anchors with names.
# --------------------------------------------------------------------------------
# Page 1 of 32 from document 8-K/A contained 1 tables.
# Page 2 of 32 from document 8-K/A contained 0 tables.
# Page 3 of 32 from document 8-K/A contained 0 tables.
# Page 4 of 32 from document 8-K/A contained 1 tables.
# Page 5 of 32 from document 8-K/A contained 1 tables.
# Page 6 of 32 from document 8-K/A contained 1 tables.
# Page 7 of 32 from document 8-K/A contained 1 tables.
# Page 8 of 32 from document 8-K/A contained 1 tables.
# Page 9 of 32 from document 8-K/A contained 0 tables.
# Page 10 of 32 from document 8-K/A contained 1 tables.
# Page 11 of 32 from document 8-K/A contained 1 tables.
# Page 12 of 32 from document 8-K/A contained 1 tables.
# Page 13 of 32 from document 8-K/A contained 1 tables.
# Page 14 of 32 from document 8-K/A contained 1 tables.
# Page 15 of 32 from document 8-K/A contained 1 tables.
# Page 16 of 32 from document 8-K/A contained 1 tables.
# Page 17 of 32 from document 8-K/A contained 1 tables.
# Page 18 of 32 from document 8-K/A contained 1 tables.
# Page 19 of 32 from document 8-K/A contained 1 tables.
# Page 20 of 32 from document 8-K/A contained 0 tables.
# Page 21 of 32 from document 8-K/A contained 0 tables.
# Page 22 of 32 from document 8-K/A contained 1 tables.
# Page 23 of 32 from document 8-K/A contained 1 tables.
# Page 24 of 32 from document 8-K/A contained 1 tables.
# Page 25 of 32 from document 8-K/A contained 1 tables.
# Page 26 of 32 from document 8-K/A contained 2 tables.
# Page 27 of 32 from document 8-K/A contained 2 tables.
# Page 28 of 32 from document 8-K/A contained 2 tables.
# Page 29 of 32 from document 8-K/A contained 1 tables.
# Page 30 of 32 from document 8-K/A contained 1 tables.
# Page 31 of 32 from document 8-K/A contained 1 tables.
# Page 32 of 32 from document 8-K/A contained 0 tables.
# All the pages from document 8-K/A have been scraped for tables.
# --------------------------------------------------------------------------------
# Page 1 of 38 from document EX-2.1 has been searched.
# Page 2 of 38 from document EX-2.1 has been searched.
# Page 3 of 38 from document EX-2.1 has been searched.
# Page 4 of 38 from document EX-2.1 has been searched.
# Page 5 of 38 from document EX-2.1 has been searched.
# Page 6 of 38 from document EX-2.1 has been searched.
# Page 7 of 38 from document EX-2.1 has been searched.
# Page 8 of 38 from document EX-2.1 has been searched.
# Page 9 of 38 from document EX-2.1 has been searched.
# Page 10 of 38 from document EX-2.1 has been searched.
# Page 11 of 38 from document EX-2.1 has been searched.
# Page 12 of 38 from document EX-2.1 has been searched.
# Page 13 of 38 from document EX-2.1 has been searched.
# Page 14 of 38 from document EX-2.1 has been searched.
# Page 15 of 38 from document EX-2.1 has been searched.
# Page 16 of 38 from document EX-2.1 has been searched.
# Page 17 of 38 from document EX-2.1 has been searched.
# Page 18 of 38 from document EX-2.1 has been searched.
# Page 19 of 38 from document EX-2.1 has been searched.
# Page 20 of 38 from document EX-2.1 has been searched.
# Page 21 of 38 from document EX-2.1 has been searched.
# Page 22 of 38 from document EX-2.1 has been searched.
# Page 23 of 38 from document EX-2.1 has been searched.
# Page 24 of 38 from document EX-2.1 has been searched.
# Page 25 of 38 from document EX-2.1 has been searched.
# Page 26 of 38 from document EX-2.1 has been searched.
# Page 27 of 38 from document EX-2.1 has been searched.
# Page 28 of 38 from document EX-2.1 has been searched.
# Page 29 of 38 from document EX-2.1 has been searched.
# Page 30 of 38 from document EX-2.1 has been searched.
# Page 31 of 38 from document EX-2.1 has been searched.
# Page 32 of 38 from document EX-2.1 has been searched.
# Page 33 of 38 from document EX-2.1 has been searched.
# Page 34 of 38 from document EX-2.1 has been searched.
# Page 35 of 38 from document EX-2.1 has been searched.
# Page 36 of 38 from document EX-2.1 has been searched.
# Page 37 of 38 from document EX-2.1 has been searched.
# Page 38 of 38 from document EX-2.1 has been searched.
# --------------------------------------------------------------------------------
# All the pages from document EX-2.1 have been searched.
# Page 1 of 38 from document EX-2.1 contained 0 anchors with names.
# Page 2 of 38 from document EX-2.1 contained 0 anchors with names.
# Page 3 of 38 from document EX-2.1 contained 0 anchors with names.
# Page 4 of 38 from document EX-2.1 contained 0 anchors with names.
# Page 5 of 38 from document EX-2.1 contained 0 anchors with names.
# Page 6 of 38 from document EX-2.1 contained 0 anchors with names.
# Page 7 of 38 from document EX-2.1 contained 0 anchors with names.
# Page 8 of 38 from document EX-2.1 contained 0 anchors with names.
# Page 9 of 38 from document EX-2.1 contained 0 anchors with names.
# Page 10 of 38 from document EX-2.1 contained 0 anchors with names.
# Page 11 of 38 from document EX-2.1 contained 0 anchors with names.
# Page 12 of 38 from document EX-2.1 contained 0 anchors with names.
# Page 13 of 38 from document EX-2.1 contained 0 anchors with names.
# Page 14 of 38 from document EX-2.1 contained 0 anchors with names.
# Page 15 of 38 from document EX-2.1 contained 0 anchors with names.
# Page 16 of 38 from document EX-2.1 contained 0 anchors with names.
# Page 17 of 38 from document EX-2.1 contained 0 anchors with names.
# Page 18 of 38 from document EX-2.1 contained 0 anchors with names.
# Page 19 of 38 from document EX-2.1 contained 0 anchors with names.
# Page 20 of 38 from document EX-2.1 contained 0 anchors with names.
# Page 21 of 38 from document EX-2.1 contained 0 anchors with names.
# Page 22 of 38 from document EX-2.1 contained 0 anchors with names.
# Page 23 of 38 from document EX-2.1 contained 0 anchors with names.
# Page 24 of 38 from document EX-2.1 contained 0 anchors with names.
# Page 25 of 38 from document EX-2.1 contained 0 anchors with names.
# Page 26 of 38 from document EX-2.1 contained 0 anchors with names.
# Page 27 of 38 from document EX-2.1 contained 0 anchors with names.
# Page 28 of 38 from document EX-2.1 contained 0 anchors with names.
# Page 29 of 38 from document EX-2.1 contained 0 anchors with names.
# Page 30 of 38 from document EX-2.1 contained 0 anchors with names.
# Page 31 of 38 from document EX-2.1 contained 0 anchors with names.
# Page 32 of 38 from document EX-2.1 contained 0 anchors with names.
# Page 33 of 38 from document EX-2.1 contained 0 anchors with names.
# Page 34 of 38 from document EX-2.1 contained 0 anchors with names.
# Page 35 of 38 from document EX-2.1 contained 0 anchors with names.
# Page 36 of 38 from document EX-2.1 contained 0 anchors with names.
# Page 37 of 38 from document EX-2.1 contained 0 anchors with names.
# Page 38 of 38 from document EX-2.1 contained 0 anchors with names.
# All the pages from document EX-2.1 have been scraped for anchors with names.
# --------------------------------------------------------------------------------
# Page 1 of 38 from document EX-2.1 contained 0 tables.
# Page 2 of 38 from document EX-2.1 contained 0 tables.
# Page 3 of 38 from document EX-2.1 contained 0 tables.
# Page 4 of 38 from document EX-2.1 contained 0 tables.
# Page 5 of 38 from document EX-2.1 contained 0 tables.
# Page 6 of 38 from document EX-2.1 contained 0 tables.
# Page 7 of 38 from document EX-2.1 contained 0 tables.
# Page 8 of 38 from document EX-2.1 contained 0 tables.
# Page 9 of 38 from document EX-2.1 contained 0 tables.
# Page 10 of 38 from document EX-2.1 contained 0 tables.
# Page 11 of 38 from document EX-2.1 contained 0 tables.
# Page 12 of 38 from document EX-2.1 contained 0 tables.
# Page 13 of 38 from document EX-2.1 contained 0 tables.
# Page 14 of 38 from document EX-2.1 contained 0 tables.
# Page 15 of 38 from document EX-2.1 contained 0 tables.
# Page 16 of 38 from document EX-2.1 contained 0 tables.
# Page 17 of 38 from document EX-2.1 contained 0 tables.
# Page 18 of 38 from document EX-2.1 contained 0 tables.
# Page 19 of 38 from document EX-2.1 contained 0 tables.
# Page 20 of 38 from document EX-2.1 contained 0 tables.
# Page 21 of 38 from document EX-2.1 contained 0 tables.
# Page 22 of 38 from document EX-2.1 contained 0 tables.
# Page 23 of 38 from document EX-2.1 contained 0 tables.
# Page 24 of 38 from document EX-2.1 contained 0 tables.
# Page 25 of 38 from document EX-2.1 contained 0 tables.
# Page 26 of 38 from document EX-2.1 contained 0 tables.
# Page 27 of 38 from document EX-2.1 contained 0 tables.
# Page 28 of 38 from document EX-2.1 contained 0 tables.
# Page 29 of 38 from document EX-2.1 contained 0 tables.
# Page 30 of 38 from document EX-2.1 contained 0 tables.
# Page 31 of 38 from document EX-2.1 contained 0 tables.
# Page 32 of 38 from document EX-2.1 contained 1 tables.
# Page 33 of 38 from document EX-2.1 contained 1 tables.
# Page 34 of 38 from document EX-2.1 contained 1 tables.
# Page 35 of 38 from document EX-2.1 contained 1 tables.
# Page 36 of 38 from document EX-2.1 contained 0 tables.
# Page 37 of 38 from document EX-2.1 contained 1 tables.
# Page 38 of 38 from document EX-2.1 contained 0 tables.
# All the pages from document EX-2.1 have been scraped for tables.
# --------------------------------------------------------------------------------
# Page 1 of 36 from document EX-4.1 has been searched.
# Page 2 of 36 from document EX-4.1 has been searched.
# Page 3 of 36 from document EX-4.1 has been searched.
# Page 4 of 36 from document EX-4.1 has been searched.
# Page 5 of 36 from document EX-4.1 has been searched.
# Page 6 of 36 from document EX-4.1 has been searched.
# Page 7 of 36 from document EX-4.1 has been searched.
# Page 8 of 36 from document EX-4.1 has been searched.
# Page 9 of 36 from document EX-4.1 has been searched.
# Page 10 of 36 from document EX-4.1 has been searched.
# Page 11 of 36 from document EX-4.1 has been searched.
# Page 12 of 36 from document EX-4.1 has been searched.
# Page 13 of 36 from document EX-4.1 has been searched.
# Page 14 of 36 from document EX-4.1 has been searched.
# Page 15 of 36 from document EX-4.1 has been searched.
# Page 16 of 36 from document EX-4.1 has been searched.
# Page 17 of 36 from document EX-4.1 has been searched.
# Page 18 of 36 from document EX-4.1 has been searched.
# Page 19 of 36 from document EX-4.1 has been searched.
# Page 20 of 36 from document EX-4.1 has been searched.
# Page 21 of 36 from document EX-4.1 has been searched.
# Page 22 of 36 from document EX-4.1 has been searched.
# Page 23 of 36 from document EX-4.1 has been searched.
# Page 24 of 36 from document EX-4.1 has been searched.
# Page 25 of 36 from document EX-4.1 has been searched.
# Page 26 of 36 from document EX-4.1 has been searched.
# Page 27 of 36 from document EX-4.1 has been searched.
# Page 28 of 36 from document EX-4.1 has been searched.
# Page 29 of 36 from document EX-4.1 has been searched.
# Page 30 of 36 from document EX-4.1 has been searched.
# Page 31 of 36 from document EX-4.1 has been searched.
# Page 32 of 36 from document EX-4.1 has been searched.
# Page 33 of 36 from document EX-4.1 has been searched.
# Page 34 of 36 from document EX-4.1 has been searched.
# Page 35 of 36 from document EX-4.1 has been searched.
# Page 36 of 36 from document EX-4.1 has been searched.
# --------------------------------------------------------------------------------
# All the pages from document EX-4.1 have been searched.
# Page 1 of 36 from document EX-4.1 contained 0 anchors with names.
# Page 2 of 36 from document EX-4.1 contained 0 anchors with names.
# Page 3 of 36 from document EX-4.1 contained 0 anchors with names.
# Page 4 of 36 from document EX-4.1 contained 0 anchors with names.
# Page 5 of 36 from document EX-4.1 contained 0 anchors with names.
# Page 6 of 36 from document EX-4.1 contained 0 anchors with names.
# Page 7 of 36 from document EX-4.1 contained 0 anchors with names.
# Page 8 of 36 from document EX-4.1 contained 0 anchors with names.
# Page 9 of 36 from document EX-4.1 contained 0 anchors with names.
# Page 10 of 36 from document EX-4.1 contained 0 anchors with names.
# Page 11 of 36 from document EX-4.1 contained 0 anchors with names.
# Page 12 of 36 from document EX-4.1 contained 0 anchors with names.
# Page 13 of 36 from document EX-4.1 contained 0 anchors with names.
# Page 14 of 36 from document EX-4.1 contained 0 anchors with names.
# Page 15 of 36 from document EX-4.1 contained 0 anchors with names.
# Page 16 of 36 from document EX-4.1 contained 0 anchors with names.
# Page 17 of 36 from document EX-4.1 contained 0 anchors with names.
# Page 18 of 36 from document EX-4.1 contained 0 anchors with names.
# Page 19 of 36 from document EX-4.1 contained 0 anchors with names.
# Page 20 of 36 from document EX-4.1 contained 0 anchors with names.
# Page 21 of 36 from document EX-4.1 contained 0 anchors with names.
# Page 22 of 36 from document EX-4.1 contained 0 anchors with names.
# Page 23 of 36 from document EX-4.1 contained 0 anchors with names.
# Page 24 of 36 from document EX-4.1 contained 0 anchors with names.
# Page 25 of 36 from document EX-4.1 contained 0 anchors with names.
# Page 26 of 36 from document EX-4.1 contained 0 anchors with names.
# Page 27 of 36 from document EX-4.1 contained 0 anchors with names.
# Page 28 of 36 from document EX-4.1 contained 0 anchors with names.
# Page 29 of 36 from document EX-4.1 contained 0 anchors with names.
# Page 30 of 36 from document EX-4.1 contained 0 anchors with names.
# Page 31 of 36 from document EX-4.1 contained 0 anchors with names.
# Page 32 of 36 from document EX-4.1 contained 0 anchors with names.
# Page 33 of 36 from document EX-4.1 contained 0 anchors with names.
# Page 34 of 36 from document EX-4.1 contained 0 anchors with names.
# Page 35 of 36 from document EX-4.1 contained 0 anchors with names.
# Page 36 of 36 from document EX-4.1 contained 0 anchors with names.
# All the pages from document EX-4.1 have been scraped for anchors with names.
# --------------------------------------------------------------------------------
# Page 1 of 36 from document EX-4.1 contained 0 tables.
# Page 2 of 36 from document EX-4.1 contained 0 tables.
# Page 3 of 36 from document EX-4.1 contained 0 tables.
# Page 4 of 36 from document EX-4.1 contained 0 tables.
# Page 5 of 36 from document EX-4.1 contained 0 tables.
# Page 6 of 36 from document EX-4.1 contained 0 tables.
# Page 7 of 36 from document EX-4.1 contained 0 tables.
# Page 8 of 36 from document EX-4.1 contained 0 tables.
# Page 9 of 36 from document EX-4.1 contained 0 tables.
# Page 10 of 36 from document EX-4.1 contained 0 tables.
# Page 11 of 36 from document EX-4.1 contained 0 tables.
# Page 12 of 36 from document EX-4.1 contained 0 tables.
# Page 13 of 36 from document EX-4.1 contained 0 tables.
# Page 14 of 36 from document EX-4.1 contained 0 tables.
# Page 15 of 36 from document EX-4.1 contained 0 tables.
# Page 16 of 36 from document EX-4.1 contained 0 tables.
# Page 17 of 36 from document EX-4.1 contained 0 tables.
# Page 18 of 36 from document EX-4.1 contained 0 tables.
# Page 19 of 36 from document EX-4.1 contained 0 tables.
# Page 20 of 36 from document EX-4.1 contained 0 tables.
# Page 21 of 36 from document EX-4.1 contained 0 tables.
# Page 22 of 36 from document EX-4.1 contained 0 tables.
# Page 23 of 36 from document EX-4.1 contained 0 tables.
# Page 24 of 36 from document EX-4.1 contained 0 tables.
# Page 25 of 36 from document EX-4.1 contained 0 tables.
# Page 26 of 36 from document EX-4.1 contained 1 tables.
# Page 27 of 36 from document EX-4.1 contained 1 tables.
# Page 28 of 36 from document EX-4.1 contained 1 tables.
# Page 29 of 36 from document EX-4.1 contained 1 tables.
# Page 30 of 36 from document EX-4.1 contained 0 tables.
# Page 31 of 36 from document EX-4.1 contained 0 tables.
# Page 32 of 36 from document EX-4.1 contained 0 tables.
# Page 33 of 36 from document EX-4.1 contained 0 tables.
# Page 34 of 36 from document EX-4.1 contained 1 tables.
# Page 35 of 36 from document EX-4.1 contained 0 tables.
# Page 36 of 36 from document EX-4.1 contained 0 tables.
# All the pages from document EX-4.1 have been scraped for tables.
# --------------------------------------------------------------------------------
# Page 1 of 21 from document EX-4.2 has been searched.
# Page 2 of 21 from document EX-4.2 has been searched.
# Page 3 of 21 from document EX-4.2 has been searched.
# Page 4 of 21 from document EX-4.2 has been searched.
# Page 5 of 21 from document EX-4.2 has been searched.
# Page 6 of 21 from document EX-4.2 has been searched.
# Page 7 of 21 from document EX-4.2 has been searched.
# Page 8 of 21 from document EX-4.2 has been searched.
# Page 9 of 21 from document EX-4.2 has been searched.
# Page 10 of 21 from document EX-4.2 has been searched.
# Page 11 of 21 from document EX-4.2 has been searched.
# Page 12 of 21 from document EX-4.2 has been searched.
# Page 13 of 21 from document EX-4.2 has been searched.
# Page 14 of 21 from document EX-4.2 has been searched.
# Page 15 of 21 from document EX-4.2 has been searched.
# Page 16 of 21 from document EX-4.2 has been searched.
# Page 17 of 21 from document EX-4.2 has been searched.
# Page 18 of 21 from document EX-4.2 has been searched.
# Page 19 of 21 from document EX-4.2 has been searched.
# Page 20 of 21 from document EX-4.2 has been searched.
# Page 21 of 21 from document EX-4.2 has been searched.
# --------------------------------------------------------------------------------
# All the pages from document EX-4.2 have been searched.
# Page 1 of 21 from document EX-4.2 contained 0 anchors with names.
# Page 2 of 21 from document EX-4.2 contained 0 anchors with names.
# Page 3 of 21 from document EX-4.2 contained 0 anchors with names.
# Page 4 of 21 from document EX-4.2 contained 0 anchors with names.
# Page 5 of 21 from document EX-4.2 contained 0 anchors with names.
# Page 6 of 21 from document EX-4.2 contained 0 anchors with names.
# Page 7 of 21 from document EX-4.2 contained 0 anchors with names.
# Page 8 of 21 from document EX-4.2 contained 0 anchors with names.
# Page 9 of 21 from document EX-4.2 contained 0 anchors with names.
# Page 10 of 21 from document EX-4.2 contained 0 anchors with names.
# Page 11 of 21 from document EX-4.2 contained 0 anchors with names.
# Page 12 of 21 from document EX-4.2 contained 0 anchors with names.
# Page 13 of 21 from document EX-4.2 contained 0 anchors with names.
# Page 14 of 21 from document EX-4.2 contained 0 anchors with names.
# Page 15 of 21 from document EX-4.2 contained 0 anchors with names.
# Page 16 of 21 from document EX-4.2 contained 0 anchors with names.
# Page 17 of 21 from document EX-4.2 contained 0 anchors with names.
# Page 18 of 21 from document EX-4.2 contained 0 anchors with names.
# Page 19 of 21 from document EX-4.2 contained 0 anchors with names.
# Page 20 of 21 from document EX-4.2 contained 0 anchors with names.
# Page 21 of 21 from document EX-4.2 contained 0 anchors with names.
# All the pages from document EX-4.2 have been scraped for anchors with names.
# --------------------------------------------------------------------------------
# Page 1 of 21 from document EX-4.2 contained 0 tables.
# Page 2 of 21 from document EX-4.2 contained 0 tables.
# Page 3 of 21 from document EX-4.2 contained 0 tables.
# Page 4 of 21 from document EX-4.2 contained 0 tables.
# Page 5 of 21 from document EX-4.2 contained 0 tables.
# Page 6 of 21 from document EX-4.2 contained 0 tables.
# Page 7 of 21 from document EX-4.2 contained 0 tables.
# Page 8 of 21 from document EX-4.2 contained 0 tables.
# Page 9 of 21 from document EX-4.2 contained 0 tables.
# Page 10 of 21 from document EX-4.2 contained 0 tables.
# Page 11 of 21 from document EX-4.2 contained 0 tables.
# Page 12 of 21 from document EX-4.2 contained 0 tables.
# Page 13 of 21 from document EX-4.2 contained 0 tables.
# Page 14 of 21 from document EX-4.2 contained 0 tables.
# Page 15 of 21 from document EX-4.2 contained 0 tables.
# Page 16 of 21 from document EX-4.2 contained 0 tables.
# Page 17 of 21 from document EX-4.2 contained 1 tables.
# Page 18 of 21 from document EX-4.2 contained 1 tables.
# Page 19 of 21 from document EX-4.2 contained 1 tables.
# Page 20 of 21 from document EX-4.2 contained 1 tables.
# Page 21 of 21 from document EX-4.2 contained 0 tables.
# All the pages from document EX-4.2 have been scraped for tables.
# --------------------------------------------------------------------------------
# Page 1 of 1 from document EX-23.1 has been searched.
# --------------------------------------------------------------------------------
# All the pages from document EX-23.1 have been searched.
# Page 1 of 1 from document EX-23.1 contained 0 anchors with names.
# All the pages from document EX-23.1 have been scraped for anchors with names.
# --------------------------------------------------------------------------------
# Page 1 of 1 from document EX-23.1 contained 0 tables.
# All the pages from document EX-23.1 have been scraped for tables.
# --------------------------------------------------------------------------------
# Page 1 of 236 from document EX-99.1 has been searched.
# Page 2 of 236 from document EX-99.1 has been searched.
# Page 3 of 236 from document EX-99.1 has been searched.
# Page 4 of 236 from document EX-99.1 has been searched.
# Page 5 of 236 from document EX-99.1 has been searched.
# Page 6 of 236 from document EX-99.1 has been searched.
# Page 7 of 236 from document EX-99.1 has been searched.
# Page 8 of 236 from document EX-99.1 has been searched.
# Page 9 of 236 from document EX-99.1 has been searched.
# Page 10 of 236 from document EX-99.1 has been searched.
# Page 11 of 236 from document EX-99.1 has been searched.
# Page 12 of 236 from document EX-99.1 has been searched.
# Page 13 of 236 from document EX-99.1 has been searched.
# Page 14 of 236 from document EX-99.1 has been searched.
# Page 15 of 236 from document EX-99.1 has been searched.
# Page 16 of 236 from document EX-99.1 has been searched.
# Page 17 of 236 from document EX-99.1 has been searched.
# Page 18 of 236 from document EX-99.1 has been searched.
# Page 19 of 236 from document EX-99.1 has been searched.
# Page 20 of 236 from document EX-99.1 has been searched.
# Page 21 of 236 from document EX-99.1 has been searched.
# Page 22 of 236 from document EX-99.1 has been searched.
# Page 23 of 236 from document EX-99.1 has been searched.
# Page 24 of 236 from document EX-99.1 has been searched.
# Page 25 of 236 from document EX-99.1 has been searched.
# Page 26 of 236 from document EX-99.1 has been searched.
# Page 27 of 236 from document EX-99.1 has been searched.
# Page 28 of 236 from document EX-99.1 has been searched.
# Page 29 of 236 from document EX-99.1 has been searched.
# Page 30 of 236 from document EX-99.1 has been searched.
# Page 31 of 236 from document EX-99.1 has been searched.
# Page 32 of 236 from document EX-99.1 has been searched.
# Page 33 of 236 from document EX-99.1 has been searched.
# Page 34 of 236 from document EX-99.1 has been searched.
# Page 35 of 236 from document EX-99.1 has been searched.
# Page 36 of 236 from document EX-99.1 has been searched.
# Page 37 of 236 from document EX-99.1 has been searched.
# Page 38 of 236 from document EX-99.1 has been searched.
# Page 39 of 236 from document EX-99.1 has been searched.
# Page 40 of 236 from document EX-99.1 has been searched.
# Page 41 of 236 from document EX-99.1 has been searched.
# Page 42 of 236 from document EX-99.1 has been searched.
# Page 43 of 236 from document EX-99.1 has been searched.
# Page 44 of 236 from document EX-99.1 has been searched.
# Page 45 of 236 from document EX-99.1 has been searched.
# Page 46 of 236 from document EX-99.1 has been searched.
# Page 47 of 236 from document EX-99.1 has been searched.
# Page 48 of 236 from document EX-99.1 has been searched.
# Page 49 of 236 from document EX-99.1 has been searched.
# Page 50 of 236 from document EX-99.1 has been searched.
# Page 51 of 236 from document EX-99.1 has been searched.
# Page 52 of 236 from document EX-99.1 has been searched.
# Page 53 of 236 from document EX-99.1 has been searched.
# Page 54 of 236 from document EX-99.1 has been searched.
# Page 55 of 236 from document EX-99.1 has been searched.
# Page 56 of 236 from document EX-99.1 has been searched.
# Page 57 of 236 from document EX-99.1 has been searched.
# Page 58 of 236 from document EX-99.1 has been searched.
# Page 59 of 236 from document EX-99.1 has been searched.
# Page 60 of 236 from document EX-99.1 has been searched.
# Page 61 of 236 from document EX-99.1 has been searched.
# Page 62 of 236 from document EX-99.1 has been searched.
# Page 63 of 236 from document EX-99.1 has been searched.
# Page 64 of 236 from document EX-99.1 has been searched.
# Page 65 of 236 from document EX-99.1 has been searched.
# Page 66 of 236 from document EX-99.1 has been searched.
# Page 67 of 236 from document EX-99.1 has been searched.
# Page 68 of 236 from document EX-99.1 has been searched.
# Page 69 of 236 from document EX-99.1 has been searched.
# Page 70 of 236 from document EX-99.1 has been searched.
# Page 71 of 236 from document EX-99.1 has been searched.
# Page 72 of 236 from document EX-99.1 has been searched.
# Page 73 of 236 from document EX-99.1 has been searched.
# Page 74 of 236 from document EX-99.1 has been searched.
# Page 75 of 236 from document EX-99.1 has been searched.
# Page 76 of 236 from document EX-99.1 has been searched.
# Page 77 of 236 from document EX-99.1 has been searched.
# Page 78 of 236 from document EX-99.1 has been searched.
# Page 79 of 236 from document EX-99.1 has been searched.
# Page 80 of 236 from document EX-99.1 has been searched.
# Page 81 of 236 from document EX-99.1 has been searched.
# Page 82 of 236 from document EX-99.1 has been searched.
# Page 83 of 236 from document EX-99.1 has been searched.
# Page 84 of 236 from document EX-99.1 has been searched.
# Page 85 of 236 from document EX-99.1 has been searched.
# Page 86 of 236 from document EX-99.1 has been searched.
# Page 87 of 236 from document EX-99.1 has been searched.
# Page 88 of 236 from document EX-99.1 has been searched.
# Page 89 of 236 from document EX-99.1 has been searched.
# Page 90 of 236 from document EX-99.1 has been searched.
# Page 91 of 236 from document EX-99.1 has been searched.
# Page 92 of 236 from document EX-99.1 has been searched.
# Page 93 of 236 from document EX-99.1 has been searched.
# Page 94 of 236 from document EX-99.1 has been searched.
# Page 95 of 236 from document EX-99.1 has been searched.
# Page 96 of 236 from document EX-99.1 has been searched.
# Page 97 of 236 from document EX-99.1 has been searched.
# Page 98 of 236 from document EX-99.1 has been searched.
# Page 99 of 236 from document EX-99.1 has been searched.
# Page 100 of 236 from document EX-99.1 has been searched.
# Page 101 of 236 from document EX-99.1 has been searched.
# Page 102 of 236 from document EX-99.1 has been searched.
# Page 103 of 236 from document EX-99.1 has been searched.
# Page 104 of 236 from document EX-99.1 has been searched.
# Page 105 of 236 from document EX-99.1 has been searched.
# Page 106 of 236 from document EX-99.1 has been searched.
# Page 107 of 236 from document EX-99.1 has been searched.
# Page 108 of 236 from document EX-99.1 has been searched.
# Page 109 of 236 from document EX-99.1 has been searched.
# Page 110 of 236 from document EX-99.1 has been searched.
# Page 111 of 236 from document EX-99.1 has been searched.
# Page 112 of 236 from document EX-99.1 has been searched.
# Page 113 of 236 from document EX-99.1 has been searched.
# Page 114 of 236 from document EX-99.1 has been searched.
# Page 115 of 236 from document EX-99.1 has been searched.
# Page 116 of 236 from document EX-99.1 has been searched.
# Page 117 of 236 from document EX-99.1 has been searched.
# Page 118 of 236 from document EX-99.1 has been searched.
# Page 119 of 236 from document EX-99.1 has been searched.
# Page 120 of 236 from document EX-99.1 has been searched.
# Page 121 of 236 from document EX-99.1 has been searched.
# Page 122 of 236 from document EX-99.1 has been searched.
# Page 123 of 236 from document EX-99.1 has been searched.
# Page 124 of 236 from document EX-99.1 has been searched.
# Page 125 of 236 from document EX-99.1 has been searched.
# Page 126 of 236 from document EX-99.1 has been searched.
# Page 127 of 236 from document EX-99.1 has been searched.
# Page 128 of 236 from document EX-99.1 has been searched.
# Page 129 of 236 from document EX-99.1 has been searched.
# Page 130 of 236 from document EX-99.1 has been searched.
# Page 131 of 236 from document EX-99.1 has been searched.
# Page 132 of 236 from document EX-99.1 has been searched.
# Page 133 of 236 from document EX-99.1 has been searched.
# Page 134 of 236 from document EX-99.1 has been searched.
# Page 135 of 236 from document EX-99.1 has been searched.
# Page 136 of 236 from document EX-99.1 has been searched.
# Page 137 of 236 from document EX-99.1 has been searched.
# Page 138 of 236 from document EX-99.1 has been searched.
# Page 139 of 236 from document EX-99.1 has been searched.
# Page 140 of 236 from document EX-99.1 has been searched.
# Page 141 of 236 from document EX-99.1 has been searched.
# Page 142 of 236 from document EX-99.1 has been searched.
# Page 143 of 236 from document EX-99.1 has been searched.
# Page 144 of 236 from document EX-99.1 has been searched.
# Page 145 of 236 from document EX-99.1 has been searched.
# Page 146 of 236 from document EX-99.1 has been searched.
# Page 147 of 236 from document EX-99.1 has been searched.
# Page 148 of 236 from document EX-99.1 has been searched.
# Page 149 of 236 from document EX-99.1 has been searched.
# Page 150 of 236 from document EX-99.1 has been searched.
# Page 151 of 236 from document EX-99.1 has been searched.
# Page 152 of 236 from document EX-99.1 has been searched.
# Page 153 of 236 from document EX-99.1 has been searched.
# Page 154 of 236 from document EX-99.1 has been searched.
# Page 155 of 236 from document EX-99.1 has been searched.
# Page 156 of 236 from document EX-99.1 has been searched.
# Page 157 of 236 from document EX-99.1 has been searched.
# Page 158 of 236 from document EX-99.1 has been searched.
# Page 159 of 236 from document EX-99.1 has been searched.
# Page 160 of 236 from document EX-99.1 has been searched.
# Page 161 of 236 from document EX-99.1 has been searched.
# Page 162 of 236 from document EX-99.1 has been searched.
# Page 163 of 236 from document EX-99.1 has been searched.
# Page 164 of 236 from document EX-99.1 has been searched.
# Page 165 of 236 from document EX-99.1 has been searched.
# Page 166 of 236 from document EX-99.1 has been searched.
# Page 167 of 236 from document EX-99.1 has been searched.
# Page 168 of 236 from document EX-99.1 has been searched.
# Page 169 of 236 from document EX-99.1 has been searched.
# Page 170 of 236 from document EX-99.1 has been searched.
# Page 171 of 236 from document EX-99.1 has been searched.
# Page 172 of 236 from document EX-99.1 has been searched.
# Page 173 of 236 from document EX-99.1 has been searched.
# Page 174 of 236 from document EX-99.1 has been searched.
# Page 175 of 236 from document EX-99.1 has been searched.
# Page 176 of 236 from document EX-99.1 has been searched.
# Page 177 of 236 from document EX-99.1 has been searched.
# Page 178 of 236 from document EX-99.1 has been searched.
# Page 179 of 236 from document EX-99.1 has been searched.
# Page 180 of 236 from document EX-99.1 has been searched.
# Page 181 of 236 from document EX-99.1 has been searched.
# Page 182 of 236 from document EX-99.1 has been searched.
# Page 183 of 236 from document EX-99.1 has been searched.
# Page 184 of 236 from document EX-99.1 has been searched.
# Page 185 of 236 from document EX-99.1 has been searched.
# Page 186 of 236 from document EX-99.1 has been searched.
# Page 187 of 236 from document EX-99.1 has been searched.
# Page 188 of 236 from document EX-99.1 has been searched.
# Page 189 of 236 from document EX-99.1 has been searched.
# Page 190 of 236 from document EX-99.1 has been searched.
# Page 191 of 236 from document EX-99.1 has been searched.
# Page 192 of 236 from document EX-99.1 has been searched.
# Page 193 of 236 from document EX-99.1 has been searched.
# Page 194 of 236 from document EX-99.1 has been searched.
# Page 195 of 236 from document EX-99.1 has been searched.
# Page 196 of 236 from document EX-99.1 has been searched.
# Page 197 of 236 from document EX-99.1 has been searched.
# Page 198 of 236 from document EX-99.1 has been searched.
# Page 199 of 236 from document EX-99.1 has been searched.
# Page 200 of 236 from document EX-99.1 has been searched.
# Page 201 of 236 from document EX-99.1 has been searched.
# Page 202 of 236 from document EX-99.1 has been searched.
# Page 203 of 236 from document EX-99.1 has been searched.
# Page 204 of 236 from document EX-99.1 has been searched.
# Page 205 of 236 from document EX-99.1 has been searched.
# Page 206 of 236 from document EX-99.1 has been searched.
# Page 207 of 236 from document EX-99.1 has been searched.
# Page 208 of 236 from document EX-99.1 has been searched.
# Page 209 of 236 from document EX-99.1 has been searched.
# Page 210 of 236 from document EX-99.1 has been searched.
# Page 211 of 236 from document EX-99.1 has been searched.
# Page 212 of 236 from document EX-99.1 has been searched.
# Page 213 of 236 from document EX-99.1 has been searched.
# Page 214 of 236 from document EX-99.1 has been searched.
# Page 215 of 236 from document EX-99.1 has been searched.
# Page 216 of 236 from document EX-99.1 has been searched.
# Page 217 of 236 from document EX-99.1 has been searched.
# Page 218 of 236 from document EX-99.1 has been searched.
# Page 219 of 236 from document EX-99.1 has been searched.
# Page 220 of 236 from document EX-99.1 has been searched.
# Page 221 of 236 from document EX-99.1 has been searched.
# Page 222 of 236 from document EX-99.1 has been searched.
# Page 223 of 236 from document EX-99.1 has been searched.
# Page 224 of 236 from document EX-99.1 has been searched.
# Page 225 of 236 from document EX-99.1 has been searched.
# Page 226 of 236 from document EX-99.1 has been searched.
# Page 227 of 236 from document EX-99.1 has been searched.
# Page 228 of 236 from document EX-99.1 has been searched.
# Page 229 of 236 from document EX-99.1 has been searched.
# Page 230 of 236 from document EX-99.1 has been searched.
# Page 231 of 236 from document EX-99.1 has been searched.
# Page 232 of 236 from document EX-99.1 has been searched.
# Page 233 of 236 from document EX-99.1 has been searched.
# Page 234 of 236 from document EX-99.1 has been searched.
# Page 235 of 236 from document EX-99.1 has been searched.
# Page 236 of 236 from document EX-99.1 has been searched.
# --------------------------------------------------------------------------------
# All the pages from document EX-99.1 have been searched.
# Page 1 of 236 from document EX-99.1 contained 0 anchors with names.
# Page 2 of 236 from document EX-99.1 contained 0 anchors with names.
# Page 3 of 236 from document EX-99.1 contained 0 anchors with names.
# Page 4 of 236 from document EX-99.1 contained 0 anchors with names.
# Page 5 of 236 from document EX-99.1 contained 0 anchors with names.
# Page 6 of 236 from document EX-99.1 contained 0 anchors with names.
# Page 7 of 236 from document EX-99.1 contained 0 anchors with names.
# Page 8 of 236 from document EX-99.1 contained 0 anchors with names.
# Page 9 of 236 from document EX-99.1 contained 2 anchors with names.
# Page 10 of 236 from document EX-99.1 contained 0 anchors with names.
# Page 11 of 236 from document EX-99.1 contained 0 anchors with names.
# Page 12 of 236 from document EX-99.1 contained 0 anchors with names.
# Page 13 of 236 from document EX-99.1 contained 0 anchors with names.
# Page 14 of 236 from document EX-99.1 contained 0 anchors with names.
# Page 15 of 236 from document EX-99.1 contained 0 anchors with names.
# Page 16 of 236 from document EX-99.1 contained 0 anchors with names.
# Page 17 of 236 from document EX-99.1 contained 0 anchors with names.
# Page 18 of 236 from document EX-99.1 contained 0 anchors with names.
# Page 19 of 236 from document EX-99.1 contained 0 anchors with names.
# Page 20 of 236 from document EX-99.1 contained 0 anchors with names.
# Page 21 of 236 from document EX-99.1 contained 0 anchors with names.
# Page 22 of 236 from document EX-99.1 contained 0 anchors with names.
# Page 23 of 236 from document EX-99.1 contained 0 anchors with names.
# Page 24 of 236 from document EX-99.1 contained 0 anchors with names.
# Page 25 of 236 from document EX-99.1 contained 0 anchors with names.
# Page 26 of 236 from document EX-99.1 contained 0 anchors with names.
# Page 27 of 236 from document EX-99.1 contained 0 anchors with names.
# Page 28 of 236 from document EX-99.1 contained 0 anchors with names.
# Page 29 of 236 from document EX-99.1 contained 0 anchors with names.
# Page 30 of 236 from document EX-99.1 contained 0 anchors with names.
# Page 31 of 236 from document EX-99.1 contained 0 anchors with names.
# Page 32 of 236 from document EX-99.1 contained 0 anchors with names.
# Page 33 of 236 from document EX-99.1 contained 0 anchors with names.
# Page 34 of 236 from document EX-99.1 contained 4 anchors with names.
# Page 35 of 236 from document EX-99.1 contained 4 anchors with names.
# Page 36 of 236 from document EX-99.1 contained 0 anchors with names.
# Page 37 of 236 from document EX-99.1 contained 1 anchors with names.
# Page 38 of 236 from document EX-99.1 contained 1 anchors with names.
# Page 39 of 236 from document EX-99.1 contained 2 anchors with names.
# Page 40 of 236 from document EX-99.1 contained 3 anchors with names.
# Page 41 of 236 from document EX-99.1 contained 1 anchors with names.
# Page 42 of 236 from document EX-99.1 contained 0 anchors with names.
# Page 43 of 236 from document EX-99.1 contained 1 anchors with names.
# Page 44 of 236 from document EX-99.1 contained 2 anchors with names.
# Page 45 of 236 from document EX-99.1 contained 0 anchors with names.
# Page 46 of 236 from document EX-99.1 contained 0 anchors with names.
# Page 47 of 236 from document EX-99.1 contained 0 anchors with names.
# Page 48 of 236 from document EX-99.1 contained 0 anchors with names.
# Page 49 of 236 from document EX-99.1 contained 0 anchors with names.
# Page 50 of 236 from document EX-99.1 contained 0 anchors with names.
# Page 51 of 236 from document EX-99.1 contained 2 anchors with names.
# Page 52 of 236 from document EX-99.1 contained 1 anchors with names.
# Page 53 of 236 from document EX-99.1 contained 2 anchors with names.
# Page 54 of 236 from document EX-99.1 contained 5 anchors with names.
# Page 55 of 236 from document EX-99.1 contained 0 anchors with names.
# Page 56 of 236 from document EX-99.1 contained 0 anchors with names.
# Page 57 of 236 from document EX-99.1 contained 0 anchors with names.
# Page 58 of 236 from document EX-99.1 contained 0 anchors with names.
# Page 59 of 236 from document EX-99.1 contained 1 anchors with names.
# Page 60 of 236 from document EX-99.1 contained 4 anchors with names.
# Page 61 of 236 from document EX-99.1 contained 6 anchors with names.
# Page 62 of 236 from document EX-99.1 contained 3 anchors with names.
# Page 63 of 236 from document EX-99.1 contained 3 anchors with names.
# Page 64 of 236 from document EX-99.1 contained 5 anchors with names.
# Page 65 of 236 from document EX-99.1 contained 3 anchors with names.
# Page 66 of 236 from document EX-99.1 contained 2 anchors with names.
# Page 67 of 236 from document EX-99.1 contained 3 anchors with names.
# Page 68 of 236 from document EX-99.1 contained 3 anchors with names.
# Page 69 of 236 from document EX-99.1 contained 3 anchors with names.
# Page 70 of 236 from document EX-99.1 contained 3 anchors with names.
# Page 71 of 236 from document EX-99.1 contained 2 anchors with names.
# Page 72 of 236 from document EX-99.1 contained 1 anchors with names.
# Page 73 of 236 from document EX-99.1 contained 2 anchors with names.
# Page 74 of 236 from document EX-99.1 contained 2 anchors with names.
# Page 75 of 236 from document EX-99.1 contained 2 anchors with names.
# Page 76 of 236 from document EX-99.1 contained 5 anchors with names.
# Page 77 of 236 from document EX-99.1 contained 3 anchors with names.
# Page 78 of 236 from document EX-99.1 contained 3 anchors with names.
# Page 79 of 236 from document EX-99.1 contained 0 anchors with names.
# Page 80 of 236 from document EX-99.1 contained 0 anchors with names.
# Page 81 of 236 from document EX-99.1 contained 1 anchors with names.
# Page 82 of 236 from document EX-99.1 contained 4 anchors with names.
# Page 83 of 236 from document EX-99.1 contained 0 anchors with names.
# Page 84 of 236 from document EX-99.1 contained 1 anchors with names.
# Page 85 of 236 from document EX-99.1 contained 2 anchors with names.
# Page 86 of 236 from document EX-99.1 contained 2 anchors with names.
# Page 87 of 236 from document EX-99.1 contained 2 anchors with names.
# Page 88 of 236 from document EX-99.1 contained 3 anchors with names.
# Page 89 of 236 from document EX-99.1 contained 0 anchors with names.
# Page 90 of 236 from document EX-99.1 contained 1 anchors with names.
# Page 91 of 236 from document EX-99.1 contained 2 anchors with names.
# Page 92 of 236 from document EX-99.1 contained 1 anchors with names.
# Page 93 of 236 from document EX-99.1 contained 2 anchors with names.
# Page 94 of 236 from document EX-99.1 contained 0 anchors with names.
# Page 95 of 236 from document EX-99.1 contained 0 anchors with names.
# Page 96 of 236 from document EX-99.1 contained 1 anchors with names.
# Page 97 of 236 from document EX-99.1 contained 2 anchors with names.
# Page 98 of 236 from document EX-99.1 contained 5 anchors with names.
# Page 99 of 236 from document EX-99.1 contained 1 anchors with names.
# Page 100 of 236 from document EX-99.1 contained 1 anchors with names.
# Page 101 of 236 from document EX-99.1 contained 4 anchors with names.
# Page 102 of 236 from document EX-99.1 contained 1 anchors with names.
# Page 103 of 236 from document EX-99.1 contained 0 anchors with names.
# Page 104 of 236 from document EX-99.1 contained 0 anchors with names.
# Page 105 of 236 from document EX-99.1 contained 0 anchors with names.
# Page 106 of 236 from document EX-99.1 contained 0 anchors with names.
# Page 107 of 236 from document EX-99.1 contained 0 anchors with names.
# Page 108 of 236 from document EX-99.1 contained 0 anchors with names.
# Page 109 of 236 from document EX-99.1 contained 1 anchors with names.
# Page 110 of 236 from document EX-99.1 contained 1 anchors with names.
# Page 111 of 236 from document EX-99.1 contained 0 anchors with names.
# Page 112 of 236 from document EX-99.1 contained 1 anchors with names.
# Page 113 of 236 from document EX-99.1 contained 1 anchors with names.
# Page 114 of 236 from document EX-99.1 contained 1 anchors with names.
# Page 115 of 236 from document EX-99.1 contained 0 anchors with names.
# Page 116 of 236 from document EX-99.1 contained 0 anchors with names.
# Page 117 of 236 from document EX-99.1 contained 0 anchors with names.
# Page 118 of 236 from document EX-99.1 contained 0 anchors with names.
# Page 119 of 236 from document EX-99.1 contained 0 anchors with names.
# Page 120 of 236 from document EX-99.1 contained 0 anchors with names.
# Page 121 of 236 from document EX-99.1 contained 1 anchors with names.
# Page 122 of 236 from document EX-99.1 contained 1 anchors with names.
# Page 123 of 236 from document EX-99.1 contained 0 anchors with names.
# Page 124 of 236 from document EX-99.1 contained 1 anchors with names.
# Page 125 of 236 from document EX-99.1 contained 0 anchors with names.
# Page 126 of 236 from document EX-99.1 contained 0 anchors with names.
# Page 127 of 236 from document EX-99.1 contained 1 anchors with names.
# Page 128 of 236 from document EX-99.1 contained 0 anchors with names.
# Page 129 of 236 from document EX-99.1 contained 0 anchors with names.
# Page 130 of 236 from document EX-99.1 contained 1 anchors with names.
# Page 131 of 236 from document EX-99.1 contained 0 anchors with names.
# Page 132 of 236 from document EX-99.1 contained 1 anchors with names.
# Page 133 of 236 from document EX-99.1 contained 0 anchors with names.
# Page 134 of 236 from document EX-99.1 contained 1 anchors with names.
# Page 135 of 236 from document EX-99.1 contained 0 anchors with names.
# Page 136 of 236 from document EX-99.1 contained 0 anchors with names.
# Page 137 of 236 from document EX-99.1 contained 0 anchors with names.
# Page 138 of 236 from document EX-99.1 contained 0 anchors with names.
# Page 139 of 236 from document EX-99.1 contained 0 anchors with names.
# Page 140 of 236 from document EX-99.1 contained 0 anchors with names.
# Page 141 of 236 from document EX-99.1 contained 0 anchors with names.
# Page 142 of 236 from document EX-99.1 contained 0 anchors with names.
# Page 143 of 236 from document EX-99.1 contained 1 anchors with names.
# Page 144 of 236 from document EX-99.1 contained 0 anchors with names.
# ...
# Page 13 of 236 from document EX-99.1 contained 0 tables.
# Page 14 of 236 from document EX-99.1 contained 0 tables.
# Page 15 of 236 from document EX-99.1 contained 0 tables.
# Page 16 of 236 from document EX-99.1 contained 0 tables.
# Page 17 of 236 from document EX-99.1 contained 0 tables.
# Page 18 of 236 from document EX-99.1 contained 0 tables.
# Page 19 of 236 from document EX-99.1 contained 0 tables.
# Page 20 of 236 from document EX-99.1 contained 0 tables.
# Page 21 of 236 from document EX-99.1 contained 0 tables.
# Page 22 of 236 from document EX-99.1 contained 0 tables.
# Page 23 of 236 from document EX-99.1 contained 0 tables.
# Page 24 of 236 from document EX-99.1 contained 0 tables.
# Page 25 of 236 from document EX-99.1 contained 0 tables.
# Page 26 of 236 from document EX-99.1 contained 0 tables.
# Page 27 of 236 from document EX-99.1 contained 0 tables.
# Page 28 of 236 from document EX-99.1 contained 0 tables.
# Page 29 of 236 from document EX-99.1 contained 0 tables.
# Page 30 of 236 from document EX-99.1 contained 0 tables.
# Page 31 of 236 from document EX-99.1 contained 0 tables.
# Page 32 of 236 from document EX-99.1 contained 0 tables.
# Page 33 of 236 from document EX-99.1 contained 0 tables.
# Page 34 of 236 from document EX-99.1 contained 0 tables.
# Page 35 of 236 from document EX-99.1 contained 0 tables.
# Page 36 of 236 from document EX-99.1 contained 0 tables.
# Page 37 of 236 from document EX-99.1 contained 0 tables.
# Page 38 of 236 from document EX-99.1 contained 0 tables.
# Page 39 of 236 from document EX-99.1 contained 0 tables.
# Page 40 of 236 from document EX-99.1 contained 0 tables.
# Page 41 of 236 from document EX-99.1 contained 0 tables.
# Page 42 of 236 from document EX-99.1 contained 0 tables.
# Page 43 of 236 from document EX-99.1 contained 0 tables.
# Page 44 of 236 from document EX-99.1 contained 0 tables.
# Page 45 of 236 from document EX-99.1 contained 0 tables.
# Page 46 of 236 from document EX-99.1 contained 0 tables.
# Page 47 of 236 from document EX-99.1 contained 0 tables.
# Page 48 of 236 from document EX-99.1 contained 0 tables.
# Page 49 of 236 from document EX-99.1 contained 0 tables.
# Page 50 of 236 from document EX-99.1 contained 0 tables.
# Page 51 of 236 from document EX-99.1 contained 0 tables.
# Page 52 of 236 from document EX-99.1 contained 0 tables.
# Page 53 of 236 from document EX-99.1 contained 0 tables.
# Page 54 of 236 from document EX-99.1 contained 0 tables.
# Page 55 of 236 from document EX-99.1 contained 0 tables.
# Page 56 of 236 from document EX-99.1 contained 0 tables.
# Page 57 of 236 from document EX-99.1 contained 0 tables.
# Page 58 of 236 from document EX-99.1 contained 0 tables.
# Page 59 of 236 from document EX-99.1 contained 0 tables.
# Page 60 of 236 from document EX-99.1 contained 0 tables.
# Page 61 of 236 from document EX-99.1 contained 0 tables.
# Page 62 of 236 from document EX-99.1 contained 0 tables.
# Page 63 of 236 from document EX-99.1 contained 0 tables.
# Page 64 of 236 from document EX-99.1 contained 0 tables.
# Page 65 of 236 from document EX-99.1 contained 0 tables.
# Page 66 of 236 from document EX-99.1 contained 0 tables.
# Page 67 of 236 from document EX-99.1 contained 0 tables.
# Page 68 of 236 from document EX-99.1 contained 0 tables.
# Page 69 of 236 from document EX-99.1 contained 0 tables.
# Page 70 of 236 from document EX-99.1 contained 0 tables.
# Page 71 of 236 from document EX-99.1 contained 0 tables.
# Page 72 of 236 from document EX-99.1 contained 0 tables.
# Page 73 of 236 from document EX-99.1 contained 0 tables.
# Page 74 of 236 from document EX-99.1 contained 0 tables.
# Page 75 of 236 from document EX-99.1 contained 0 tables.
# Page 76 of 236 from document EX-99.1 contained 0 tables.
# Page 77 of 236 from document EX-99.1 contained 0 tables.
# Page 78 of 236 from document EX-99.1 contained 0 tables.
# Page 79 of 236 from document EX-99.1 contained 0 tables.
# Page 80 of 236 from document EX-99.1 contained 0 tables.
# Page 81 of 236 from document EX-99.1 contained 0 tables.
# Page 82 of 236 from document EX-99.1 contained 0 tables.
# Page 83 of 236 from document EX-99.1 contained 0 tables.
# Page 84 of 236 from document EX-99.1 contained 0 tables.
# Page 85 of 236 from document EX-99.1 contained 0 tables.
# Page 86 of 236 from document EX-99.1 contained 0 tables.
# Page 87 of 236 from document EX-99.1 contained 0 tables.
# Page 88 of 236 from document EX-99.1 contained 0 tables.
# Page 89 of 236 from document EX-99.1 contained 0 tables.
# Page 90 of 236 from document EX-99.1 contained 0 tables.
# Page 91 of 236 from document EX-99.1 contained 0 tables.
# Page 92 of 236 from document EX-99.1 contained 0 tables.
# Page 93 of 236 from document EX-99.1 contained 0 tables.
# Page 94 of 236 from document EX-99.1 contained 0 tables.
# Page 95 of 236 from document EX-99.1 contained 0 tables.
# Page 96 of 236 from document EX-99.1 contained 0 tables.
# Page 97 of 236 from document EX-99.1 contained 0 tables.
# Page 98 of 236 from document EX-99.1 contained 0 tables.
# Page 99 of 236 from document EX-99.1 contained 0 tables.
# Page 100 of 236 from document EX-99.1 contained 0 tables.
# Page 101 of 236 from document EX-99.1 contained 0 tables.
# Page 102 of 236 from document EX-99.1 contained 0 tables.
# Page 103 of 236 from document EX-99.1 contained 1 tables.
# Page 104 of 236 from document EX-99.1 contained 1 tables.
# Page 105 of 236 from document EX-99.1 contained 1 tables.
# Page 106 of 236 from document EX-99.1 contained 1 tables.
# Page 107 of 236 from document EX-99.1 contained 1 tables.
# Page 108 of 236 from document EX-99.1 contained 1 tables.
# Page 109 of 236 from document EX-99.1 contained 1 tables.
# Page 110 of 236 from document EX-99.1 contained 1 tables.
# Page 111 of 236 from document EX-99.1 contained 1 tables.
# Page 112 of 236 from document EX-99.1 contained 1 tables.
# Page 113 of 236 from document EX-99.1 contained 0 tables.
# Page 114 of 236 from document EX-99.1 contained 0 tables.
# Page 115 of 236 from document EX-99.1 contained 0 tables.
# Page 116 of 236 from document EX-99.1 contained 0 tables.
# Page 117 of 236 from document EX-99.1 contained 0 tables.
# Page 118 of 236 from document EX-99.1 contained 0 tables.
# Page 119 of 236 from document EX-99.1 contained 2 tables.
# Page 120 of 236 from document EX-99.1 contained 1 tables.
# Page 121 of 236 from document EX-99.1 contained 0 tables.
# Page 122 of 236 from document EX-99.1 contained 0 tables.
# Page 123 of 236 from document EX-99.1 contained 0 tables.
# Page 124 of 236 from document EX-99.1 contained 1 tables.
# Page 125 of 236 from document EX-99.1 contained 1 tables.
# Page 126 of 236 from document EX-99.1 contained 1 tables.
# Page 127 of 236 from document EX-99.1 contained 1 tables.
# Page 128 of 236 from document EX-99.1 contained 3 tables.
# Page 129 of 236 from document EX-99.1 contained 1 tables.
# Page 130 of 236 from document EX-99.1 contained 1 tables.
# Page 131 of 236 from document EX-99.1 contained 1 tables.
# Page 132 of 236 from document EX-99.1 contained 1 tables.
# Page 133 of 236 from document EX-99.1 contained 1 tables.
# Page 134 of 236 from document EX-99.1 contained 0 tables.
# Page 135 of 236 from document EX-99.1 contained 1 tables.
# Page 136 of 236 from document EX-99.1 contained 1 tables.
# Page 137 of 236 from document EX-99.1 contained 1 tables.
# Page 138 of 236 from document EX-99.1 contained 1 tables.
# Page 139 of 236 from document EX-99.1 contained 1 tables.
# Page 140 of 236 from document EX-99.1 contained 0 tables.
# Page 141 of 236 from document EX-99.1 contained 2 tables.
# Page 142 of 236 from document EX-99.1 contained 1 tables.
# Page 143 of 236 from document EX-99.1 contained 1 tables.
# Page 144 of 236 from document EX-99.1 contained 3 tables.
# Page 145 of 236 from document EX-99.1 contained 1 tables.
# Page 146 of 236 from document EX-99.1 contained 0 tables.
# Page 147 of 236 from document EX-99.1 contained 0 tables.
# Page 148 of 236 from document EX-99.1 contained 0 tables.
# Page 149 of 236 from document EX-99.1 contained 0 tables.
# Page 150 of 236 from document EX-99.1 contained 0 tables.
# Page 151 of 236 from document EX-99.1 contained 0 tables.
# Page 152 of 236 from document EX-99.1 contained 0 tables.
# Page 153 of 236 from document EX-99.1 contained 0 tables.
# Page 154 of 236 from document EX-99.1 contained 0 tables.
# Page 155 of 236 from document EX-99.1 contained 0 tables.
# Page 156 of 236 from document EX-99.1 contained 0 tables.
# Page 157 of 236 from document EX-99.1 contained 1 tables.
# Page 158 of 236 from document EX-99.1 contained 0 tables.
# Page 159 of 236 from document EX-99.1 contained 0 tables.
# Page 160 of 236 from document EX-99.1 contained 0 tables.
# Page 161 of 236 from document EX-99.1 contained 0 tables.
# Page 162 of 236 from document EX-99.1 contained 0 tables.
# Page 163 of 236 from document EX-99.1 contained 0 tables.
# Page 164 of 236 from document EX-99.1 contained 0 tables.
# Page 165 of 236 from document EX-99.1 contained 0 tables.
# Page 166 of 236 from document EX-99.1 contained 0 tables.
# Page 167 of 236 from document EX-99.1 contained 0 tables.
# Page 168 of 236 from document EX-99.1 contained 0 tables.
# Page 169 of 236 from document EX-99.1 contained 0 tables.
# Page 170 of 236 from document EX-99.1 contained 0 tables.
# Page 171 of 236 from document EX-99.1 contained 1 tables.
# Page 172 of 236 from document EX-99.1 contained 1 tables.
# Page 173 of 236 from document EX-99.1 contained 1 tables.
# Page 174 of 236 from document EX-99.1 contained 1 tables.
# Page 175 of 236 from document EX-99.1 contained 1 tables.
# Page 176 of 236 from document EX-99.1 contained 1 tables.
# Page 177 of 236 from document EX-99.1 contained 1 tables.
# Page 178 of 236 from document EX-99.1 contained 1 tables.
# Page 179 of 236 from document EX-99.1 contained 0 tables.
# Page 180 of 236 from document EX-99.1 contained 0 tables.
# Page 181 of 236 from document EX-99.1 contained 0 tables.
# Page 182 of 236 from document EX-99.1 contained 0 tables.
# Page 183 of 236 from document EX-99.1 contained 0 tables.
# Page 184 of 236 from document EX-99.1 contained 0 tables.
# Page 185 of 236 from document EX-99.1 contained 0 tables.
# Page 186 of 236 from document EX-99.1 contained 0 tables.
# Page 187 of 236 from document EX-99.1 contained 0 tables.
# Page 188 of 236 from document EX-99.1 contained 0 tables.
# Page 189 of 236 from document EX-99.1 contained 1 tables.
# Page 190 of 236 from document EX-99.1 contained 0 tables.
# Page 191 of 236 from document EX-99.1 contained 0 tables.
# Page 192 of 236 from document EX-99.1 contained 0 tables.
# Page 193 of 236 from document EX-99.1 contained 0 tables.
# Page 194 of 236 from document EX-99.1 contained 0 tables.
# Page 195 of 236 from document EX-99.1 contained 0 tables.
# Page 196 of 236 from document EX-99.1 contained 0 tables.
# Page 197 of 236 from document EX-99.1 contained 0 tables.
# Page 198 of 236 from document EX-99.1 contained 0 tables.
# Page 199 of 236 from document EX-99.1 contained 0 tables.
# Page 200 of 236 from document EX-99.1 contained 0 tables.
# Page 201 of 236 from document EX-99.1 contained 0 tables.
# Page 202 of 236 from document EX-99.1 contained 0 tables.
# Page 203 of 236 from document EX-99.1 contained 0 tables.
# Page 204 of 236 from document EX-99.1 contained 0 tables.
# Page 205 of 236 from document EX-99.1 contained 0 tables.
# Page 206 of 236 from document EX-99.1 contained 0 tables.
# Page 207 of 236 from document EX-99.1 contained 0 tables.
# Page 208 of 236 from document EX-99.1 contained 0 tables.
# Page 209 of 236 from document EX-99.1 contained 0 tables.
# Page 210 of 236 from document EX-99.1 contained 0 tables.
# Page 211 of 236 from document EX-99.1 contained 0 tables.
# Page 212 of 236 from document EX-99.1 contained 0 tables.
# Page 213 of 236 from document EX-99.1 contained 0 tables.
# Page 214 of 236 from document EX-99.1 contained 0 tables.
# Page 215 of 236 from document EX-99.1 contained 0 tables.
# Page 216 of 236 from document EX-99.1 contained 0 tables.
# Page 217 of 236 from document EX-99.1 contained 0 tables.
# Page 218 of 236 from document EX-99.1 contained 0 tables.
# Page 219 of 236 from document EX-99.1 contained 0 tables.
# Page 220 of 236 from document EX-99.1 contained 0 tables.
# Page 221 of 236 from document EX-99.1 contained 0 tables.
# Page 222 of 236 from document EX-99.1 contained 0 tables.
# Page 223 of 236 from document EX-99.1 contained 0 tables.
# Page 224 of 236 from document EX-99.1 contained 0 tables.
# Page 225 of 236 from document EX-99.1 contained 1 tables.
# Page 226 of 236 from document EX-99.1 contained 1 tables.
# Page 227 of 236 from document EX-99.1 contained 0 tables.
# Page 228 of 236 from document EX-99.1 contained 0 tables.
# Page 229 of 236 from document EX-99.1 contained 0 tables.
# Page 230 of 236 from document EX-99.1 contained 0 tables.
# Page 231 of 236 from document EX-99.1 contained 0 tables.
# Page 232 of 236 from document EX-99.1 contained 1 tables.
# Page 233 of 236 from document EX-99.1 contained 0 tables.
# Page 234 of 236 from document EX-99.1 contained 1 tables.
# Page 235 of 236 from document EX-99.1 contained 0 tables.
# Page 236 of 236 from document EX-99.1 contained 0 tables.
# All the pages from document EX-99.1 have been scraped for tables.
# --------------------------------------------------------------------------------
# Page 1 of 14 from document EX-99.2 has been searched.
# Page 2 of 14 from document EX-99.2 has been searched.
# Page 3 of 14 from document EX-99.2 has been searched.
# Page 4 of 14 from document EX-99.2 has been searched.
# Page 5 of 14 from document EX-99.2 has been searched.
# Page 6 of 14 from document EX-99.2 has been searched.
# Page 7 of 14 from document EX-99.2 has been searched.
# Page 8 of 14 from document EX-99.2 has been searched.
# Page 9 of 14 from document EX-99.2 has been searched.
# Page 10 of 14 from document EX-99.2 has been searched.
# Page 11 of 14 from document EX-99.2 has been searched.
# Page 12 of 14 from document EX-99.2 has been searched.
# Page 13 of 14 from document EX-99.2 has been searched.
# Page 14 of 14 from document EX-99.2 has been searched.
# --------------------------------------------------------------------------------
# All the pages from document EX-99.2 have been searched.
# Page 1 of 14 from document EX-99.2 contained 0 anchors with names.
# Page 2 of 14 from document EX-99.2 contained 0 anchors with names.
# Page 3 of 14 from document EX-99.2 contained 0 anchors with names.
# Page 4 of 14 from document EX-99.2 contained 0 anchors with names.
# Page 5 of 14 from document EX-99.2 contained 0 anchors with names.
# Page 6 of 14 from document EX-99.2 contained 0 anchors with names.
# Page 7 of 14 from document EX-99.2 contained 0 anchors with names.
# Page 8 of 14 from document EX-99.2 contained 0 anchors with names.
# Page 9 of 14 from document EX-99.2 contained 0 anchors with names.
# Page 10 of 14 from document EX-99.2 contained 0 anchors with names.
# Page 11 of 14 from document EX-99.2 contained 0 anchors with names.
# Page 12 of 14 from document EX-99.2 contained 0 anchors with names.
# Page 13 of 14 from document EX-99.2 contained 0 anchors with names.
# Page 14 of 14 from document EX-99.2 contained 0 anchors with names.
# All the pages from document EX-99.2 have been scraped for anchors with names.
# --------------------------------------------------------------------------------
# Page 1 of 14 from document EX-99.2 contained 0 tables.
# Page 2 of 14 from document EX-99.2 contained 0 tables.
# Page 3 of 14 from document EX-99.2 contained 0 tables.
# Page 4 of 14 from document EX-99.2 contained 0 tables.
# Page 5 of 14 from document EX-99.2 contained 0 tables.
# Page 6 of 14 from document EX-99.2 contained 1 tables.
# Page 7 of 14 from document EX-99.2 contained 1 tables.
# Page 8 of 14 from document EX-99.2 contained 1 tables.
# Page 9 of 14 from document EX-99.2 contained 1 tables.
# Page 10 of 14 from document EX-99.2 contained 1 tables.
# Page 11 of 14 from document EX-99.2 contained 1 tables.
# Page 12 of 14 from document EX-99.2 contained 1 tables.
# Page 13 of 14 from document EX-99.2 contained 1 tables.
# Page 14 of 14 from document EX-99.2 contained 0 tables.
# All the pages from document EX-99.2 have been scraped for tables.
# --------------------------------------------------------------------------------

# %% [markdown]
# ## Scraping Tables
# Now I know for some of you that you'll want to scrape the tables. I've provided a function you can use that will take your tables dictionary and parse each table to the best of its ability. Unfortuantely this might not return perfect results, but it's a good starting point for you to build off of.
#
# One of the biggest challenges is that tables are formatted with blank rows and columns. Making it difficult to determine the "true" number of rows and columns.

# %%
def scrape_table_dictionary(table_dictionary):
    
    # initalize a new dicitonary that'll house all your results
    new_table_dictionary = {}
    
    if len(table_dictionary) != 0:

        # loop through the dictionary
        for table_id in table_dictionary:

            # grab the table
            table_html = table_dictionary[table_id]
            
            # grab all the rows.
            table_rows = table_html.find_all('tr')
            
            # parse the table, first loop through the rows, then each element, and then parse each element.
            parsed_table = [
                [element.get_text(strip=True) for element in row.find_all('td')]
                for row in table_rows
            ]
            
            # keep the original just to be safe.
            new_table_dictionary[table_id]['original_table'] = table_html
            
            # add the new parsed table.
            new_table_dictionary[table_id]['parsed_table'] = parsed_table
            
            # here some additional steps you can take to clean up the data - Removing '$'.
            parsed_table_cleaned = [
                [element for element in row if element != '$']
                for row in parsed_table
            ]
            
            # here some additional steps you can take to clean up the data - Removing Blanks.
            parsed_table_cleaned = [
                [element for element in row if element != None]
                for row in parsed_table_cleaned
            ]

            
    else:
        
        # if there are no tables then just have the id equal NONE
        new_table_dictionary[1]['original_table'] = None
        new_table_dictionary[1]['parsed_table'] = None
        
    return new_table_dictionary

# %% [markdown]
# ## Complex Searches
# In some cases, what you're trying to do might require doing a very complex search. For example, we might want the text that is centered over the page. This will give us context as to what is on the page and provide us more details of its content. This would fall under a "complex search," and to do a complex search, we will need to define some extra strategies we can take to find different parts of the page.
#
# The beautiful thing about BeautifulSoup is we can define functions where we set our criteria and then only return tags that match those criteria. Below I've provided some example "search functions" that will help you find precise portions of your page.
#
# ### Search For Centered Headers

# %%
def search_for_centered_headers(tag):

    # easy way to end early is check if the 'align' keet is in attributes.
    if 'align' not in tag.attrs:
        return
    
    # define the criteria.
    criteria1 = tag.name == 'p'                # I want the tag to be name of 'p'
    criteria2 = tag.parent.name != 'td'        # I want the parent tag NOT to be named 'td'
    criteria3 = tag['align'] == 'center'       # I want the 'align' attribute to be labeled 'center'.
    
    # if it matches all the criteria then return the text.
    if criteria1 and criteria2 and criteria3:         
        return tag.get_text(strip = True)

# %% [markdown]
# ## Search For Bolded Text

# %%
def search_for_bolded_tags(tag):
    
    # define the criteria.
    criteria1 = tag.name == 'b'                # I want the tag to be name of 'p'
    criteria2 = tag.parent.name != 'td'        # I want the parent tag NOT to be named 'td'
    
    # if it matches all the criteria then return the text.
    if criteria1 and criteria2:         
        return tag.get_text(strip = True).replace('\n',' ')

# %% [markdown]
# ## Using Custom Search Functions

# %%
# first grab all the documents
filing_documents = master_filings_dict[accession_number]['filing_documents']

# loop through each document
for document_id in filing_documents:   
    
    # let's grab the all pages code.
    pages_dict = filing_documents[document_id]['pages_code']  
            
    # initalize a dictionary to store all the anchors we find.
    centered_headers_dict = {}
    
    # loop through each page
    for page_num in pages_dict:
        
        # grab the actual text
        page_code = pages_dict[page_num]
        
        # find all the anchors in the page, that have the attribute 'name'
        centered_headers_found = page_code.find_all(search_for_centered_headers)
        
        # number of anchors found
        num_found = len(centered_headers_found)
   
        # display a status to the user.
        print('Page {} of {} from document {} contained {} centered headers.'.format(page_num, 
                                                                                     page_length, 
                                                                                     document_id, 
                                                                                     num_found))
    
    # display a status to the user.  
    print('All the pages from document {} have been scraped for centered headers.'.format(document_id)) 
    print('-'*80)
# Out:
# Page 1 of 14 from document 8-K/A contained 11 centered headers.
# Page 2 of 14 from document 8-K/A contained 1 centered headers.
# Page 3 of 14 from document 8-K/A contained 1 centered headers.
# Page 4 of 14 from document 8-K/A contained 1 centered headers.
# Page 5 of 14 from document 8-K/A contained 5 centered headers.
# Page 6 of 14 from document 8-K/A contained 4 centered headers.
# Page 7 of 14 from document 8-K/A contained 5 centered headers.
# Page 8 of 14 from document 8-K/A contained 4 centered headers.
# Page 9 of 14 from document 8-K/A contained 3 centered headers.
# Page 10 of 14 from document 8-K/A contained 1 centered headers.
# Page 11 of 14 from document 8-K/A contained 1 centered headers.
# Page 12 of 14 from document 8-K/A contained 1 centered headers.
# Page 13 of 14 from document 8-K/A contained 1 centered headers.
# Page 14 of 14 from document 8-K/A contained 1 centered headers.
# Page 15 of 14 from document 8-K/A contained 4 centered headers.
# Page 16 of 14 from document 8-K/A contained 1 centered headers.
# Page 17 of 14 from document 8-K/A contained 1 centered headers.
# Page 18 of 14 from document 8-K/A contained 4 centered headers.
# Page 19 of 14 from document 8-K/A contained 3 centered headers.
# Page 20 of 14 from document 8-K/A contained 1 centered headers.
# Page 21 of 14 from document 8-K/A contained 1 centered headers.
# Page 22 of 14 from document 8-K/A contained 6 centered headers.
# Page 23 of 14 from document 8-K/A contained 6 centered headers.
# Page 24 of 14 from document 8-K/A contained 4 centered headers.
# Page 25 of 14 from document 8-K/A contained 3 centered headers.
# Page 26 of 14 from document 8-K/A contained 1 centered headers.
# Page 27 of 14 from document 8-K/A contained 1 centered headers.
# Page 28 of 14 from document 8-K/A contained 1 centered headers.
# Page 29 of 14 from document 8-K/A contained 1 centered headers.
# Page 30 of 14 from document 8-K/A contained 2 centered headers.
# Page 31 of 14 from document 8-K/A contained 2 centered headers.
# Page 32 of 14 from document 8-K/A contained 0 centered headers.
# All the pages from document 8-K/A have been scraped for centered headers.
# --------------------------------------------------------------------------------
# Page 1 of 14 from document EX-2.1 contained 3 centered headers.
# Page 2 of 14 from document EX-2.1 contained 1 centered headers.
# Page 3 of 14 from document EX-2.1 contained 1 centered headers.
# Page 4 of 14 from document EX-2.1 contained 1 centered headers.
# Page 5 of 14 from document EX-2.1 contained 3 centered headers.
# Page 6 of 14 from document EX-2.1 contained 1 centered headers.
# Page 7 of 14 from document EX-2.1 contained 1 centered headers.
# Page 8 of 14 from document EX-2.1 contained 1 centered headers.
# Page 9 of 14 from document EX-2.1 contained 3 centered headers.
# Page 10 of 14 from document EX-2.1 contained 1 centered headers.
# Page 11 of 14 from document EX-2.1 contained 1 centered headers.
# Page 12 of 14 from document EX-2.1 contained 1 centered headers.
# Page 13 of 14 from document EX-2.1 contained 3 centered headers.
# Page 14 of 14 from document EX-2.1 contained 1 centered headers.
# Page 15 of 14 from document EX-2.1 contained 1 centered headers.
# Page 16 of 14 from document EX-2.1 contained 1 centered headers.
# Page 17 of 14 from document EX-2.1 contained 1 centered headers.
# Page 18 of 14 from document EX-2.1 contained 3 centered headers.
# Page 19 of 14 from document EX-2.1 contained 1 centered headers.
# Page 20 of 14 from document EX-2.1 contained 3 centered headers.
# Page 21 of 14 from document EX-2.1 contained 1 centered headers.
# Page 22 of 14 from document EX-2.1 contained 1 centered headers.
# Page 23 of 14 from document EX-2.1 contained 1 centered headers.
# Page 24 of 14 from document EX-2.1 contained 3 centered headers.
# Page 25 of 14 from document EX-2.1 contained 1 centered headers.
# Page 26 of 14 from document EX-2.1 contained 1 centered headers.
# Page 27 of 14 from document EX-2.1 contained 1 centered headers.
# Page 28 of 14 from document EX-2.1 contained 1 centered headers.
# Page 29 of 14 from document EX-2.1 contained 3 centered headers.
# Page 30 of 14 from document EX-2.1 contained 3 centered headers.
# Page 31 of 14 from document EX-2.1 contained 1 centered headers.
# Page 32 of 14 from document EX-2.1 contained 1 centered headers.
# Page 33 of 14 from document EX-2.1 contained 1 centered headers.
# Page 34 of 14 from document EX-2.1 contained 2 centered headers.
# Page 35 of 14 from document EX-2.1 contained 1 centered headers.
# Page 36 of 14 from document EX-2.1 contained 3 centered headers.
# Page 37 of 14 from document EX-2.1 contained 1 centered headers.
# Page 38 of 14 from document EX-2.1 contained 0 centered headers.
# All the pages from document EX-2.1 have been scraped for centered headers.
# --------------------------------------------------------------------------------
# Page 1 of 14 from document EX-4.1 contained 13 centered headers.
# Page 2 of 14 from document EX-4.1 contained 2 centered headers.
# Page 3 of 14 from document EX-4.1 contained 1 centered headers.
# Page 4 of 14 from document EX-4.1 contained 1 centered headers.
# Page 5 of 14 from document EX-4.1 contained 1 centered headers.
# Page 6 of 14 from document EX-4.1 contained 1 centered headers.
# Page 7 of 14 from document EX-4.1 contained 1 centered headers.
# Page 8 of 14 from document EX-4.1 contained 1 centered headers.
# Page 9 of 14 from document EX-4.1 contained 1 centered headers.
# Page 10 of 14 from document EX-4.1 contained 1 centered headers.
# Page 11 of 14 from document EX-4.1 contained 1 centered headers.
# Page 12 of 14 from document EX-4.1 contained 1 centered headers.
# Page 13 of 14 from document EX-4.1 contained 1 centered headers.
# Page 14 of 14 from document EX-4.1 contained 1 centered headers.
# Page 15 of 14 from document EX-4.1 contained 1 centered headers.
# Page 16 of 14 from document EX-4.1 contained 1 centered headers.
# Page 17 of 14 from document EX-4.1 contained 1 centered headers.
# Page 18 of 14 from document EX-4.1 contained 1 centered headers.
# Page 19 of 14 from document EX-4.1 contained 1 centered headers.
# Page 20 of 14 from document EX-4.1 contained 1 centered headers.
# Page 21 of 14 from document EX-4.1 contained 1 centered headers.
# Page 22 of 14 from document EX-4.1 contained 1 centered headers.
# Page 23 of 14 from document EX-4.1 contained 1 centered headers.
# Page 24 of 14 from document EX-4.1 contained 1 centered headers.
# Page 25 of 14 from document EX-4.1 contained 2 centered headers.
# Page 26 of 14 from document EX-4.1 contained 0 centered headers.
# Page 27 of 14 from document EX-4.1 contained 0 centered headers.
# Page 28 of 14 from document EX-4.1 contained 0 centered headers.
# Page 29 of 14 from document EX-4.1 contained 0 centered headers.
# Page 30 of 14 from document EX-4.1 contained 2 centered headers.
# Page 31 of 14 from document EX-4.1 contained 2 centered headers.
# Page 32 of 14 from document EX-4.1 contained 2 centered headers.
# Page 33 of 14 from document EX-4.1 contained 1 centered headers.
# Page 34 of 14 from document EX-4.1 contained 1 centered headers.
# Page 35 of 14 from document EX-4.1 contained 7 centered headers.
# Page 36 of 14 from document EX-4.1 contained 0 centered headers.
# All the pages from document EX-4.1 have been scraped for centered headers.
# --------------------------------------------------------------------------------
# Page 1 of 14 from document EX-4.2 contained 11 centered headers.
# Page 2 of 14 from document EX-4.2 contained 1 centered headers.
# Page 3 of 14 from document EX-4.2 contained 1 centered headers.
# Page 4 of 14 from document EX-4.2 contained 0 centered headers.
# Page 5 of 14 from document EX-4.2 contained 0 centered headers.
# Page 6 of 14 from document EX-4.2 contained 0 centered headers.
# Page 7 of 14 from document EX-4.2 contained 0 centered headers.
# Page 8 of 14 from document EX-4.2 contained 0 centered headers.
# Page 9 of 14 from document EX-4.2 contained 0 centered headers.
# Page 10 of 14 from document EX-4.2 contained 0 centered headers.
# Page 11 of 14 from document EX-4.2 contained 0 centered headers.
# Page 12 of 14 from document EX-4.2 contained 0 centered headers.
# Page 13 of 14 from document EX-4.2 contained 0 centered headers.
# Page 14 of 14 from document EX-4.2 contained 2 centered headers.
# Page 15 of 14 from document EX-4.2 contained 0 centered headers.
# Page 16 of 14 from document EX-4.2 contained 1 centered headers.
# Page 17 of 14 from document EX-4.2 contained 0 centered headers.
# Page 18 of 14 from document EX-4.2 contained 0 centered headers.
# Page 19 of 14 from document EX-4.2 contained 0 centered headers.
# Page 20 of 14 from document EX-4.2 contained 0 centered headers.
# Page 21 of 14 from document EX-4.2 contained 0 centered headers.
# All the pages from document EX-4.2 have been scraped for centered headers.
# --------------------------------------------------------------------------------
# Page 1 of 14 from document EX-23.1 contained 1 centered headers.
# All the pages from document EX-23.1 have been scraped for centered headers.
# --------------------------------------------------------------------------------
# Page 1 of 14 from document EX-99.1 contained 29 centered headers.
# Page 2 of 14 from document EX-99.1 contained 2 centered headers.
# Page 3 of 14 from document EX-99.1 contained 1 centered headers.
# Page 4 of 14 from document EX-99.1 contained 1 centered headers.
# Page 5 of 14 from document EX-99.1 contained 1 centered headers.
# Page 6 of 14 from document EX-99.1 contained 1 centered headers.
# Page 7 of 14 from document EX-99.1 contained 11 centered headers.
# Page 8 of 14 from document EX-99.1 contained 1 centered headers.
# Page 9 of 14 from document EX-99.1 contained 2 centered headers.
# Page 10 of 14 from document EX-99.1 contained 1 centered headers.
# Page 11 of 14 from document EX-99.1 contained 2 centered headers.
# Page 12 of 14 from document EX-99.1 contained 1 centered headers.
# Page 13 of 14 from document EX-99.1 contained 1 centered headers.
# Page 14 of 14 from document EX-99.1 contained 1 centered headers.
# Page 15 of 14 from document EX-99.1 contained 1 centered headers.
# Page 16 of 14 from document EX-99.1 contained 1 centered headers.
# Page 17 of 14 from document EX-99.1 contained 1 centered headers.
# Page 18 of 14 from document EX-99.1 contained 1 centered headers.
# Page 19 of 14 from document EX-99.1 contained 1 centered headers.
# Page 20 of 14 from document EX-99.1 contained 1 centered headers.
# Page 21 of 14 from document EX-99.1 contained 1 centered headers.
# Page 22 of 14 from document EX-99.1 contained 1 centered headers.
# Page 23 of 14 from document EX-99.1 contained 1 centered headers.
# Page 24 of 14 from document EX-99.1 contained 1 centered headers.
# Page 25 of 14 from document EX-99.1 contained 1 centered headers.
# Page 26 of 14 from document EX-99.1 contained 1 centered headers.
# Page 27 of 14 from document EX-99.1 contained 1 centered headers.
# Page 28 of 14 from document EX-99.1 contained 1 centered headers.
# Page 29 of 14 from document EX-99.1 contained 1 centered headers.
# Page 30 of 14 from document EX-99.1 contained 1 centered headers.
# Page 31 of 14 from document EX-99.1 contained 1 centered headers.
# Page 32 of 14 from document EX-99.1 contained 1 centered headers.
# Page 33 of 14 from document EX-99.1 contained 1 centered headers.
# Page 34 of 14 from document EX-99.1 contained 1 centered headers.
# Page 35 of 14 from document EX-99.1 contained 2 centered headers.
# Page 36 of 14 from document EX-99.1 contained 1 centered headers.
# Page 37 of 14 from document EX-99.1 contained 1 centered headers.
# Page 38 of 14 from document EX-99.1 contained 1 centered headers.
# Page 39 of 14 from document EX-99.1 contained 1 centered headers.
# Page 40 of 14 from document EX-99.1 contained 1 centered headers.
# Page 41 of 14 from document EX-99.1 contained 1 centered headers.
# Page 42 of 14 from document EX-99.1 contained 1 centered headers.
# Page 43 of 14 from document EX-99.1 contained 1 centered headers.
# Page 44 of 14 from document EX-99.1 contained 1 centered headers.
# Page 45 of 14 from document EX-99.1 contained 1 centered headers.
# Page 46 of 14 from document EX-99.1 contained 1 centered headers.
# Page 47 of 14 from document EX-99.1 contained 1 centered headers.
# Page 48 of 14 from document EX-99.1 contained 1 centered headers.
# Page 49 of 14 from document EX-99.1 contained 1 centered headers.
# Page 50 of 14 from document EX-99.1 contained 1 centered headers.
# Page 51 of 14 from document EX-99.1 contained 3 centered headers.
# Page 52 of 14 from document EX-99.1 contained 1 centered headers.
# Page 53 of 14 from document EX-99.1 contained 1 centered headers.
# Page 54 of 14 from document EX-99.1 contained 2 centered headers.
# Page 55 of 14 from document EX-99.1 contained 1 centered headers.
# Page 56 of 14 from document EX-99.1 contained 1 centered headers.
# Page 57 of 14 from document EX-99.1 contained 1 centered headers.
# Page 58 of 14 from document EX-99.1 contained 1 centered headers.
# Page 59 of 14 from document EX-99.1 contained 1 centered headers.
# Page 60 of 14 from document EX-99.1 contained 3 centered headers.
# Page 61 of 14 from document EX-99.1 contained 1 centered headers.
# Page 62 of 14 from document EX-99.1 contained 1 centered headers.
# Page 63 of 14 from document EX-99.1 contained 1 centered headers.
# Page 64 of 14 from document EX-99.1 contained 1 centered headers.
# Page 65 of 14 from document EX-99.1 contained 3 centered headers.
# Page 66 of 14 from document EX-99.1 contained 1 centered headers.
# Page 67 of 14 from document EX-99.1 contained 1 centered headers.
# Page 68 of 14 from document EX-99.1 contained 1 centered headers.
# Page 69 of 14 from document EX-99.1 contained 1 centered headers.
# Page 70 of 14 from document EX-99.1 contained 1 centered headers.
# Page 71 of 14 from document EX-99.1 contained 3 centered headers.
# Page 72 of 14 from document EX-99.1 contained 1 centered headers.
# Page 73 of 14 from document EX-99.1 contained 1 centered headers.
# Page 74 of 14 from document EX-99.1 contained 1 centered headers.
# Page 75 of 14 from document EX-99.1 contained 1 centered headers.
# Page 76 of 14 from document EX-99.1 contained 1 centered headers.
# Page 77 of 14 from document EX-99.1 contained 1 centered headers.
# Page 78 of 14 from document EX-99.1 contained 3 centered headers.
# Page 79 of 14 from document EX-99.1 contained 1 centered headers.
# Page 80 of 14 from document EX-99.1 contained 1 centered headers.
# Page 81 of 14 from document EX-99.1 contained 1 centered headers.
# Page 82 of 14 from document EX-99.1 contained 3 centered headers.
# Page 83 of 14 from document EX-99.1 contained 1 centered headers.
# Page 84 of 14 from document EX-99.1 contained 1 centered headers.
# Page 85 of 14 from document EX-99.1 contained 1 centered headers.
# Page 86 of 14 from document EX-99.1 contained 1 centered headers.
# Page 87 of 14 from document EX-99.1 contained 1 centered headers.
# Page 88 of 14 from document EX-99.1 contained 3 centered headers.
# Page 89 of 14 from document EX-99.1 contained 1 centered headers.
# Page 90 of 14 from document EX-99.1 contained 1 centered headers.
# Page 91 of 14 from document EX-99.1 contained 1 centered headers.
# Page 92 of 14 from document EX-99.1 contained 1 centered headers.
# Page 93 of 14 from document EX-99.1 contained 1 centered headers.
# Page 94 of 14 from document EX-99.1 contained 1 centered headers.
# Page 95 of 14 from document EX-99.1 contained 1 centered headers.
# Page 96 of 14 from document EX-99.1 contained 1 centered headers.
# Page 97 of 14 from document EX-99.1 contained 1 centered headers.
# Page 98 of 14 from document EX-99.1 contained 1 centered headers.
# Page 99 of 14 from document EX-99.1 contained 1 centered headers.
# Page 100 of 14 from document EX-99.1 contained 1 centered headers.
# Page 101 of 14 from document EX-99.1 contained 1 centered headers.
# Page 102 of 14 from document EX-99.1 contained 3 centered headers.
# Page 103 of 14 from document EX-99.1 contained 1 centered headers.
# Page 104 of 14 from document EX-99.1 contained 1 centered headers.
# Page 105 of 14 from document EX-99.1 contained 1 centered headers.
# Page 106 of 14 from document EX-99.1 contained 1 centered headers.
# Page 107 of 14 from document EX-99.1 contained 1 centered headers.
# Page 108 of 14 from document EX-99.1 contained 1 centered headers.
# Page 109 of 14 from document EX-99.1 contained 1 centered headers.
# Page 110 of 14 from document EX-99.1 contained 3 centered headers.
# Page 111 of 14 from document EX-99.1 contained 1 centered headers.
# Page 112 of 14 from document EX-99.1 contained 2 centered headers.
# Page 113 of 14 from document EX-99.1 contained 1 centered headers.
# Page 114 of 14 from document EX-99.1 contained 3 centered headers.
# Page 115 of 14 from document EX-99.1 contained 1 centered headers.
# Page 116 of 14 from document EX-99.1 contained 1 centered headers.
# Page 117 of 14 from document EX-99.1 contained 1 centered headers.
# Page 118 of 14 from document EX-99.1 contained 1 centered headers.
# Page 119 of 14 from document EX-99.1 contained 1 centered headers.
# Page 120 of 14 from document EX-99.1 contained 0 centered headers.
# Page 121 of 14 from document EX-99.1 contained 1 centered headers.
# Page 122 of 14 from document EX-99.1 contained 3 centered headers.
# Page 123 of 14 from document EX-99.1 contained 1 centered headers.
# Page 124 of 14 from document EX-99.1 contained 2 centered headers.
# Page 125 of 14 from document EX-99.1 contained 1 centered headers.
# Page 126 of 14 from document EX-99.1 contained 1 centered headers.
# Page 127 of 14 from document EX-99.1 contained 2 centered headers.
# Page 128 of 14 from document EX-99.1 contained 1 centered headers.
# Page 129 of 14 from document EX-99.1 contained 1 centered headers.
# Page 130 of 14 from document EX-99.1 contained 2 centered headers.
# Page 131 of 14 from document EX-99.1 contained 1 centered headers.
# Page 132 of 14 from document EX-99.1 contained 2 centered headers.
# Page 133 of 14 from document EX-99.1 contained 1 centered headers.
# Page 134 of 14 from document EX-99.1 contained 3 centered headers.
# Page 135 of 14 from document EX-99.1 contained 1 centered headers.
# Page 136 of 14 from document EX-99.1 contained 5 centered headers.
# Page 137 of 14 from document EX-99.1 contained 1 centered headers.
# Page 138 of 14 from document EX-99.1 contained 2 centered headers.
# Page 139 of 14 from document EX-99.1 contained 2 centered headers.
# Page 140 of 14 from document EX-99.1 contained 3 centered headers.
# Page 141 of 14 from document EX-99.1 contained 2 centered headers.
# Page 142 of 14 from document EX-99.1 contained 1 centered headers.
# Page 143 of 14 from document EX-99.1 contained 2 centered headers.
# Page 144 of 14 from document EX-99.1 contained 1 centered headers.
# Page 145 of 14 from document EX-99.1 contained 1 centered headers.
# Page 146 of 14 from document EX-99.1 contained 5 centered headers.
# Page 147 of 14 from document EX-99.1 contained 1 centered headers.
# Page 148 of 14 from document EX-99.1 contained 6 centered headers.
# Page 149 of 14 from document EX-99.1 contained 3 centered headers.
# Page 150 of 14 from document EX-99.1 contained 3 centered headers.
# Page 151 of 14 from document EX-99.1 contained 1 centered headers.
# Page 152 of 14 from document EX-99.1 contained 1 centered headers.
# Page 153 of 14 from document EX-99.1 contained 1 centered headers.
# Page 154 of 14 from document EX-99.1 contained 3 centered headers.
# Page 155 of 14 from document EX-99.1 contained 1 centered headers.
# Page 156 of 14 from document EX-99.1 contained 1 centered headers.
# Page 157 of 14 from document EX-99.1 contained 1 centered headers.
# Page 158 of 14 from document EX-99.1 contained 13 centered headers.
# Page 159 of 14 from document EX-99.1 contained 1 centered headers.
# Page 160 of 14 from document EX-99.1 contained 3 centered headers.
# Page 161 of 14 from document EX-99.1 contained 1 centered headers.
# Page 162 of 14 from document EX-99.1 contained 3 centered headers.
# Page 163 of 14 from document EX-99.1 contained 1 centered headers.
# Page 164 of 14 from document EX-99.1 contained 1 centered headers.
# Page 165 of 14 from document EX-99.1 contained 1 centered headers.
# Page 166 of 14 from document EX-99.1 contained 5 centered headers.
# Page 167 of 14 from document EX-99.1 contained 1 centered headers.
# Page 168 of 14 from document EX-99.1 contained 1 centered headers.
# Page 169 of 14 from document EX-99.1 contained 1 centered headers.
# Page 170 of 14 from document EX-99.1 contained 1 centered headers.
# Page 171 of 14 from document EX-99.1 contained 1 centered headers.
# Page 172 of 14 from document EX-99.1 contained 1 centered headers.
# Page 173 of 14 from document EX-99.1 contained 1 centered headers.
# Page 174 of 14 from document EX-99.1 contained 1 centered headers.
# Page 175 of 14 from document EX-99.1 contained 1 centered headers.
# Page 176 of 14 from document EX-99.1 contained 1 centered headers.
# Page 177 of 14 from document EX-99.1 contained 1 centered headers.
# Page 178 of 14 from document EX-99.1 contained 1 centered headers.
# Page 179 of 14 from document EX-99.1 contained 6 centered headers.
# Page 180 of 14 from document EX-99.1 contained 1 centered headers.
# Page 181 of 14 from document EX-99.1 contained 3 centered headers.
# Page 182 of 14 from document EX-99.1 contained 1 centered headers.
# Page 183 of 14 from document EX-99.1 contained 1 centered headers.
# Page 184 of 14 from document EX-99.1 contained 1 centered headers.
# Page 185 of 14 from document EX-99.1 contained 5 centered headers.
# Page 186 of 14 from document EX-99.1 contained 1 centered headers.
# Page 187 of 14 from document EX-99.1 contained 1 centered headers.
# Page 188 of 14 from document EX-99.1 contained 1 centered headers.
# Page 189 of 14 from document EX-99.1 contained 1 centered headers.
# Page 190 of 14 from document EX-99.1 contained 3 centered headers.
# Page 191 of 14 from document EX-99.1 contained 4 centered headers.
# Page 192 of 14 from document EX-99.1 contained 1 centered headers.
# Page 193 of 14 from document EX-99.1 contained 1 centered headers.
# Page 194 of 14 from document EX-99.1 contained 1 centered headers.
# Page 195 of 14 from document EX-99.1 contained 1 centered headers.
# Page 196 of 14 from document EX-99.1 contained 1 centered headers.
# Page 197 of 14 from document EX-99.1 contained 1 centered headers.
# Page 198 of 14 from document EX-99.1 contained 1 centered headers.
# Page 199 of 14 from document EX-99.1 contained 1 centered headers.
# Page 200 of 14 from document EX-99.1 contained 1 centered headers.
# Page 201 of 14 from document EX-99.1 contained 1 centered headers.
# Page 202 of 14 from document EX-99.1 contained 1 centered headers.
# Page 203 of 14 from document EX-99.1 contained 1 centered headers.
# Page 204 of 14 from document EX-99.1 contained 1 centered headers.
# Page 205 of 14 from document EX-99.1 contained 1 centered headers.
# Page 206 of 14 from document EX-99.1 contained 1 centered headers.
# Page 207 of 14 from document EX-99.1 contained 1 centered headers.
# Page 208 of 14 from document EX-99.1 contained 1 centered headers.
# Page 209 of 14 from document EX-99.1 contained 1 centered headers.
# Page 210 of 14 from document EX-99.1 contained 1 centered headers.
# Page 211 of 14 from document EX-99.1 contained 1 centered headers.
# Page 212 of 14 from document EX-99.1 contained 1 centered headers.
# Page 213 of 14 from document EX-99.1 contained 1 centered headers.
# Page 214 of 14 from document EX-99.1 contained 1 centered headers.
# Page 215 of 14 from document EX-99.1 contained 1 centered headers.
# Page 216 of 14 from document EX-99.1 contained 1 centered headers.
# Page 217 of 14 from document EX-99.1 contained 1 centered headers.
# Page 218 of 14 from document EX-99.1 contained 1 centered headers.
# Page 219 of 14 from document EX-99.1 contained 1 centered headers.
# Page 220 of 14 from document EX-99.1 contained 1 centered headers.
# Page 221 of 14 from document EX-99.1 contained 1 centered headers.
# Page 222 of 14 from document EX-99.1 contained 1 centered headers.
# Page 223 of 14 from document EX-99.1 contained 1 centered headers.
# Page 224 of 14 from document EX-99.1 contained 3 centered headers.
# Page 225 of 14 from document EX-99.1 contained 1 centered headers.
# Page 226 of 14 from document EX-99.1 contained 3 centered headers.
# Page 227 of 14 from document EX-99.1 contained 3 centered headers.
# Page 228 of 14 from document EX-99.1 contained 3 centered headers.
# Page 229 of 14 from document EX-99.1 contained 3 centered headers.
# Page 230 of 14 from document EX-99.1 contained 1 centered headers.
# Page 231 of 14 from document EX-99.1 contained 2 centered headers.
# Page 232 of 14 from document EX-99.1 contained 1 centered headers.
# Page 233 of 14 from document EX-99.1 contained 5 centered headers.
# Page 234 of 14 from document EX-99.1 contained 1 centered headers.
# Page 235 of 14 from document EX-99.1 contained 3 centered headers.
# Page 236 of 14 from document EX-99.1 contained 0 centered headers.
# All the pages from document EX-99.1 have been scraped for centered headers.
# --------------------------------------------------------------------------------
# Page 1 of 14 from document EX-99.2 contained 2 centered headers.
# Page 2 of 14 from document EX-99.2 contained 0 centered headers.
# Page 3 of 14 from document EX-99.2 contained 0 centered headers.
# Page 4 of 14 from document EX-99.2 contained 1 centered headers.
# Page 5 of 14 from document EX-99.2 contained 1 centered headers.
# Page 6 of 14 from document EX-99.2 contained 1 centered headers.
# Page 7 of 14 from document EX-99.2 contained 1 centered headers.
# Page 8 of 14 from document EX-99.2 contained 1 centered headers.
# Page 9 of 14 from document EX-99.2 contained 1 centered headers.
# Page 10 of 14 from document EX-99.2 contained 1 centered headers.
# Page 11 of 14 from document EX-99.2 contained 1 centered headers.
# Page 12 of 14 from document EX-99.2 contained 1 centered headers.
# Page 13 of 14 from document EX-99.2 contained 1 centered headers.
# Page 14 of 14 from document EX-99.2 contained 0 centered headers.
# All the pages from document EX-99.2 have been scraped for centered headers.
# --------------------------------------------------------------------------------

# %% [markdown]
# ## Closing Notes
# Alright at this point you understand the natural hierarchy of an SEC filing, can parse an SEC filing for it's different documents, can break those documents into pages, can normalize the text of each page, can conduct searches on those pages, can create dictionaries that follow that natural hierarchy, can parse HTML tables, and can build custom search functions.
#
# If that sounds like a lot, it's because it is. There was a lot to this series, and it's just scratching the surface. I've seen individuals take this approach and expand on it to do a wide variety of tasks. However, what I hope this provides you is a foundation to build off of. The challenging thing about parsing documents is it's easy to get lost early on. My advice to you is to keep it simple, keep it organized, and keep it clean. Most importantly, keep it organized!
#
# The easiest way to take a simple problem and make it a complex problem is not to keep the task organized. You might also be wondering where do you go from here. The simple answer is it's up to you, and it depends on what you're doing. In some cases, it might make sense to take your numeric data and some of your text data and store it in a database. In other cases, you might want to dump your results in a text file.
#
# Your best bet is to define what you want to do with the data, as this will help you determine the best strategy for long-term storage. All in all, I hoped you found this tutorial useful, and more importantly, hopefully, it can help relieve/automate some of your workloads.
